# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("df_DBSCAN_Clustering1.csv", skipinitialspace=True, sep=',')
df
# Out:
#        VehYear  VehicleAge  WheelTypeID  VehOdo  \
# 0         2001           8          1.0   55117
# 1         2001           8          1.0   55117
# 2         2006           3          1.0   80650
# 3         2006           3          1.0   72728
# 4         2006           3          1.0   72728
# ...        ...         ...          ...     ...
# 50901     2006           4          1.0   82286
# 50902     2006           4          1.0   80855
# 50903     2006           3          1.0   68976
# 50904     2006           3          1.0   68976
# 50905     2006           4          1.0   72138
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionRetailAveragePrice  \
# 0                                 3192.0                            3947.0
# 1                                 3192.0                            3947.0
# 2                                13271.0                           14833.0
# 3                                12423.0                           13917.0
# 4                                12423.0                           13917.0
# ...                                  ...                               ...
# 50901                            12341.0                           16405.0
# 50902                            10120.0                           14618.0
# 50903                            13765.0                           15366.0
# 50904                            13765.0                           15366.0
# 50905                            10184.0                           14097.0
#
#        MMRCurrentAuctionAveragePrice  MMRCurrentRetailAveragePrice  VehBCost  \
# 0                             3192.0                        3947.0    4315.0
# 1                             3192.0                        3947.0    4315.0
# 2                            12982.0                       18542.0   11515.0
# 3                            13721.0                       15319.0   10835.0
# 4                            13721.0                       15319.0   10835.0
# ...                              ...                           ...       ...
# 50901                        13115.0                       16693.0    8675.0
# 50902                        10795.0                       14669.0   10115.0
# 50903                        13981.0                       15599.0    9215.0
# 50904                        13981.0                       15599.0    9215.0
# 50905                        10110.0                       14346.0    9005.0
#
#        WarrantyCost  TotalPrice  CostOverOdo  labels_DBSCAN  Cost/Odometer
# 0              1054      5369.0     0.078288              0       0.078288
# 1              1054      5369.0     0.078288              0       0.078288
# 2               983     12498.0     0.142777              0       0.142777
# 3               920     11755.0     0.148980              0       0.148980
# 4               920     11755.0     0.148980              0       0.148980
# ...             ...         ...          ...            ...            ...
# 50901          1373     10048.0     0.105425              0       0.105425
# 50902          1373     11488.0     0.125100              0       0.125100
# 50903          1118     10333.0     0.133597              0       0.133597
# 50904          1118     10333.0     0.133597              0       0.133597
# 50905          1272     10277.0     0.124830              0       0.124830
#
# [50906 rows x 14 columns]

# %% [markdown]
# Eliminiamo gli ouliers trovati attraverso il DBSCAN

# %%
indexNames = df[df['labels_DBSCAN'] == -1 ].index
df.drop(indexNames , inplace=True)

# %%
df
# Out:
#        VehYear  VehicleAge  WheelTypeID  VehOdo  \
# 0         2001           8          1.0   55117
# 1         2001           8          1.0   55117
# 2         2006           3          1.0   80650
# 3         2006           3          1.0   72728
# 4         2006           3          1.0   72728
# ...        ...         ...          ...     ...
# 50901     2006           4          1.0   82286
# 50902     2006           4          1.0   80855
# 50903     2006           3          1.0   68976
# 50904     2006           3          1.0   68976
# 50905     2006           4          1.0   72138
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionRetailAveragePrice  \
# 0                                 3192.0                            3947.0
# 1                                 3192.0                            3947.0
# 2                                13271.0                           14833.0
# 3                                12423.0                           13917.0
# 4                                12423.0                           13917.0
# ...                                  ...                               ...
# 50901                            12341.0                           16405.0
# 50902                            10120.0                           14618.0
# 50903                            13765.0                           15366.0
# 50904                            13765.0                           15366.0
# 50905                            10184.0                           14097.0
#
#        MMRCurrentAuctionAveragePrice  MMRCurrentRetailAveragePrice  VehBCost  \
# 0                             3192.0                        3947.0    4315.0
# 1                             3192.0                        3947.0    4315.0
# 2                            12982.0                       18542.0   11515.0
# 3                            13721.0                       15319.0   10835.0
# 4                            13721.0                       15319.0   10835.0
# ...                              ...                           ...       ...
# 50901                        13115.0                       16693.0    8675.0
# 50902                        10795.0                       14669.0   10115.0
# 50903                        13981.0                       15599.0    9215.0
# 50904                        13981.0                       15599.0    9215.0
# 50905                        10110.0                       14346.0    9005.0
#
#        WarrantyCost  TotalPrice  CostOverOdo  labels_DBSCAN  Cost/Odometer
# 0              1054      5369.0     0.078288              0       0.078288
# 1              1054      5369.0     0.078288              0       0.078288
# 2               983     12498.0     0.142777              0       0.142777
# 3               920     11755.0     0.148980              0       0.148980
# 4               920     11755.0     0.148980              0       0.148980
# ...             ...         ...          ...            ...            ...
# 50901          1373     10048.0     0.105425              0       0.105425
# 50902          1373     11488.0     0.125100              0       0.125100
# 50903          1118     10333.0     0.133597              0       0.133597
# 50904          1118     10333.0     0.133597              0       0.133597
# 50905          1272     10277.0     0.124830              0       0.124830
#
# [50850 rows x 14 columns]

# %% [markdown]
# ## Inizio analisi

# %%
columns=['VehicleAge','VehOdo','MMRAcquisitionAuctionAveragePrice','VehBCost', 'WarrantyCost','Cost/Odometer']
pdf=df[columns]
pdf.head()
# Out:
#    VehicleAge  VehOdo  MMRAcquisitionAuctionAveragePrice  VehBCost  \
# 0           8   55117                             3192.0    4315.0
# 1           8   55117                             3192.0    4315.0
# 2           3   80650                            13271.0   11515.0
# 3           3   72728                            12423.0   10835.0
# 4           3   72728                            12423.0   10835.0
#
#    WarrantyCost  Cost/Odometer
# 0          1054       0.078288
# 1          1054       0.078288
# 2           983       0.142777
# 3           920       0.148980
# 4           920       0.148980

# %% [markdown]
# ### Normalization

# %%
scaler = StandardScaler()
scaler.fit(pdf.head().values)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X = scaler.fit_transform(pdf.values)

# %%
X[:5]
# Out:
# array([[ 2.19492097, -1.10439874, -1.23762279, -1.34324599, -0.35240442,
#         -0.57015854],
#        [ 2.19492097, -1.10439874, -1.23762279, -1.34324599, -0.35240442,
#         -0.57015854],
#        [-0.67490967,  0.6482156 ,  3.0030683 ,  2.7785488 , -0.46907494,
#          1.23172933],
#        [-0.67490967,  0.10444045,  2.64627635,  2.38926818, -0.57259948,
#          1.40502746],
#        [-0.67490967,  0.10444045,  2.64627635,  2.38926818, -0.57259948,
#          1.40502746]])

# %% [markdown]
# #### Knee Method to estimate the best K

# %%
sse_list = list()
max_k = 50
for k in range(2, max_k + 1):
    kmeans = KMeans(n_clusters=k, n_init=20, max_iter=150)
    kmeans.fit(X)
    
    sse = kmeans.inertia_
    sse_list.append(sse)

# %%
plt.plot(range(2, len(sse_list) + 2), sse_list)
plt.ylabel('SSE', fontsize=22)
plt.xlabel('K', fontsize=22)
plt.xticks(np.arange(0, 50, 5))
plt.tick_params(axis='both', which='major', labelsize=22)
plt.show()

# %% [markdown]
# ## Fast tests with different values of K [2, 15]

# %% [markdown]
# ### K=15

# %%
kmeans = KMeans(n_clusters=15, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=15, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE1= 'SSE %s' % kmeans.inertia_
SILH1='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE1)
print(SILH1)
# Out:
# SSE 71207.21772052196
# Silhouette 0.20991816067741484

# %% [markdown]
# ### K=14

# %%
kmeans = KMeans(n_clusters=14, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=14, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE2= 'SSE %s' % kmeans.inertia_
SILH2='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE2)
print(SILH2)
# Out:
# SSE 73839.13020475952
# Silhouette 0.21098277448244374

# %% [markdown]
# ### K=13

# %%
kmeans = KMeans(n_clusters=13, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=13, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE3= 'SSE %s' % kmeans.inertia_
SILH3='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE3)
print(SILH1)
# Out:
# SSE 77207.62219500936
# Silhouette 0.20991816067741484

# %% [markdown]
# ### K=12

# %%
kmeans = KMeans(n_clusters=12, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=12, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE4= 'SSE %s' % kmeans.inertia_
SILH4='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE4)
print(SILH4)
# Out:
# SSE 80739.28832127072
# Silhouette 0.20958882277199456

# %% [markdown]
# ### K=11

# %%
kmeans = KMeans(n_clusters=11, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=11, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE5= 'SSE %s' % kmeans.inertia_
SILH5='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE5)
print(SILH5)
# Out:
# SSE 84404.44300604552
# Silhouette 0.21384324716600717

# %% [markdown]
# ### K=10

# %%
kmeans = KMeans(n_clusters=10, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=10, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE6= 'SSE %s' % kmeans.inertia_
SILH6='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE6)
print(SILH6)
# Out:
# SSE 88473.18075279809
# Silhouette 0.21415193105416472

# %% [markdown]
# ### K=9

# %%
kmeans = KMeans(n_clusters=9, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=9, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE7= 'SSE %s' % kmeans.inertia_
SILH7='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE7)
print(SILH7)
# Out:
# SSE 92955.00629388617
# Silhouette 0.21888075972956797

# %% [markdown]
# ### K=8

# %%
kmeans = KMeans(n_clusters=8, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=8, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE8= 'SSE %s' % kmeans.inertia_
SILH8='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE8)
print(SILH8)
# Out:
# SSE 99243.67107593005
# Silhouette 0.2222650861815293

# %% [markdown]
# ### K=7

# %%
kmeans = KMeans(n_clusters=7, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=7, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE9= 'SSE %s' % kmeans.inertia_
SILH9='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE9)
print(SILH9)
# Out:
# SSE 108046.31976375284
# Silhouette 0.21273714294422577

# %% [markdown]
# ### K=6

# %%
kmeans = KMeans(n_clusters=6, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=6, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE10= 'SSE %s' % kmeans.inertia_
SILH10='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE10)
print(SILH10)
# Out:
# SSE 117265.57593394736
# Silhouette 0.21477330063487496

# %% [markdown]
# ### K=5

# %%
kmeans = KMeans(n_clusters=5, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=5, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE11= 'SSE %s' % kmeans.inertia_
SILH11='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE11)
print(SILH11)
# Out:
# SSE 129020.05012453903
# Silhouette 0.2192389998827733

# %% [markdown]
# ### K=4

# %%
kmeans = KMeans(n_clusters=4, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=4, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE12= 'SSE %s' % kmeans.inertia_
SILH12='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE12)
print(SILH12)
# Out:
# SSE 141809.35256102978
# Silhouette 0.23816382242315182

# %% [markdown]
# ### K=3

# %%
kmeans = KMeans(n_clusters=3, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=3, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE13= 'SSE %s' % kmeans.inertia_
SILH13='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE13)
print(SILH13)
# Out:
# SSE 165126.0139048403
# Silhouette 0.268927555431653

# %% [markdown]
# ### K=2

# %%
kmeans = KMeans(n_clusters=2, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=2, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
SSE14= 'SSE %s' % kmeans.inertia_
SILH14='Silhouette %s' % silhouette_score(X, kmeans.labels_)
print(SSE14)
print(SILH14)
# Out:
# SSE 205325.66626960944
# Silhouette 0.2839864797065698

# %% [markdown]
# ## Confronto SSE

# %%
print('1.', SSE1)
print('2.', SSE2 , 'Best value')
print('3.', SSE3)
print('4.', SSE4)
print('5.', SSE5)
print('6.', SSE6)
print('7.', SSE7)
print('8.', SSE8)
print('9.', SSE9)
print('10.', SSE10)
print('11.', SSE11)
print('12.', SSE12)
print('13.', SSE13)
print('14.', SSE14)
# Out:
# 1. SSE 71207.21772052196
# 2. SSE 73839.13020475952 Best value
# 3. SSE 77207.62219500936
# 4. SSE 80739.28832127072
# 5. SSE 84404.44300604552
# 6. SSE 88473.18075279809
# 7. SSE 92955.00629388617
# 8. SSE 99243.67107593005
# 9. SSE 108046.31976375284
# 10. SSE 117265.57593394736
# 11. SSE 129020.05012453903
# 12. SSE 141809.35256102978
# 13. SSE 165126.0139048403
# 14. SSE 205325.66626960944

# %% [markdown]
# ## Confronto Silhouette

# %%
print('1.', SILH1)
print('2.', SILH2)
print('3.', SILH3)
print('4.', SILH4)
print('5.', SILH5)
print('6.', SILH6)
print('7.', SILH7)
print('8.', SILH8)
print('9.', SILH9)
print('10.', SILH10)
print('11.', SILH11)
print('12.', SILH12)
print('13.', SILH13)
print('14.', SILH14, 'Best value')
# Out:
# 1. Silhouette 0.20991816067741484
# 2. Silhouette 0.21098277448244374
# 3. Silhouette 0.20288784884060856
# 4. Silhouette 0.20958882277199456
# 5. Silhouette 0.21384324716600717
# 6. Silhouette 0.21415193105416472
# 7. Silhouette 0.21888075972956797
# 8. Silhouette 0.2222650861815293
# 9. Silhouette 0.21273714294422577
# 10. Silhouette 0.21477330063487496
# 11. Silhouette 0.2192389998827733
# 12. Silhouette 0.23816382242315182
# 13. Silhouette 0.268927555431653
# 14. Silhouette 0.2839864797065698 Best value

# %% [markdown]
# Dominio SSE [71207.21772052196, 205325.66626960944]
#
# Dominio Silhouette [0.20288784884060856, 0.2839864797065698]

# %%
SSE=[71207.21772052196, 73839.13020475952, 77207.62219500936, 80739.28832127072, 84404.44300604552, 88473.18075279809,\
     92955.00629388617, 99243.67107593005, 108046.31976375284, 117265.57593394736, 129020.05012453903, 141809.35256102978,\
     165126.0139048403, 205325.66626960944]
Silhouette=[0.20991816067741484, 0.21098277448244374, 0.20288784884060856, 0.20958882277199456, 0.21384324716600717,\
            0.21415193105416472, 0.21888075972956797, 0.2222650861815293, 0.21273714294422577, 0.21477330063487496,\
            0.2192389998827733, 0.23816382242315182, 0.268927555431653, 0.2839864797065698]

# %%
import statistics

SSE.sort() 
Silhouette.sort()

m1=statistics.median_low(SSE) 
m2=statistics.median_high(Silhouette)
print('La mediana del SSE è: ', m1,)
print('La mediana della Silhouette è: ', m2)
# Out:
# La mediana del SSE è:  92955.00629388617
# La mediana della Silhouette è:  0.21477330063487496

# %%
me1=statistics.mean(SSE)
me2=statistics.mean(Silhouette)
print('Valore medio per SSE: ',me1)
print('Valore medio per Silhouette: ', me2)
# Out:
# Valore medio per SSE:  109618.7527234243
# Valore medio per Silhouette:  0.22431042370906995

# %%
for sse in SSE:
    if sse>=m1 and sse<=me1:
        print (sse)
    else:
        continue
# Out:
# 92955.00629388617
# 99243.67107593005
# 108046.31976375284

# %%
for silh in Silhouette:
    if silh>=m2 and silh<=me2:
        print (silh)
    else:
        continue
# Out:
# 0.21477330063487496
# 0.21888075972956797
# 0.2192389998827733
# 0.2222650861815293

# %% [markdown]
# Gli SSE si riferiscono al cluster 7, 8 e 9.
# Per la silhouette invece ai cluster 7, 8, 10 e 11.
# Di conseguenza la migliore combinazione dei due indici è il cluster 8, che si riferisce al valore di K=6, che adesso andremo ad analizzare in maniera più dettagliata.

# %% [markdown]
# # Analisi K=6

# %%
kmeans = KMeans(n_clusters=6, n_init=20, max_iter=150)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=150,
#        n_clusters=6, n_init=20, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
hist, bins = np.histogram(kmeans.labels_, 
                          bins=range(0, len(set(kmeans.labels_)) + 1))
dict(zip(bins, hist))
# Out:
# {0: 10219, 1: 6454, 2: 4099, 3: 12636, 4: 10141, 5: 7301}

# %%
plt.scatter(pdf['VehicleAge'], pdf['VehOdo'], 
            c=kmeans.labels_, s=20)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('VehicleAge')
plt.ylabel('VehOdo')
plt.show()

# %%
plt.scatter(pdf['VehOdo'], pdf['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('VehOdo')
plt.ylabel('MMRAcquisitionAuctionAveragePrice')
plt.show()

# %%
plt.scatter(pdf['MMRAcquisitionAuctionAveragePrice'], pdf['VehicleAge'], 
            c=kmeans.labels_, s=20)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('VehicleAge')
plt.show()

# %%
plt.scatter(pdf['Cost/Odometer'], pdf['VehicleAge'], 
            c=kmeans.labels_, s=20)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('Cost/Odometer')
plt.ylabel('VehicleAge')
plt.show()

# %%
plt.scatter(pdf['VehOdo'], pdf['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('VehOdo')
plt.ylabel('WarrantyCost')
plt.show()

# %%
plt.scatter(pdf['Cost/Odometer'], pdf['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('Cost/Odometer')
plt.ylabel('MMRAcquisitionAuctionAveragePrice')
plt.show()

# %% [markdown]
# Centroids

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.64352594,  0.57156235, -0.97664063, -1.04787803, -0.25407582,
#         -1.03707589],
#        [-1.08609073, -1.53189319,  0.57137809,  0.52309051, -0.70871868,
#          1.66121358],
#        [ 1.43135978,  0.74583962, -1.11243667, -0.9756741 ,  1.87566052,
#         -1.0287912 ],
#        [-0.19952083,  0.57436056,  0.39058659,  0.36463468,  0.48405955,
#         -0.17333779],
#        [-0.02706223, -0.81232946, -0.46317876, -0.37848179, -0.60555252,
#          0.11441948],
#        [-0.35927938,  0.2733223 ,  1.45217797,  1.44495328, -0.06614018,
#          0.69797611]])

# %% [markdown]
# Two dimentional view with the centroids

# %%
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(pdf['VehicleAge'], pdf['VehOdo'], c=kmeans.labels_, 
            s=20)
plt.scatter(centers[:, 0], centers[:, 5], s=200, marker='*', c='k')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('VehicleAge')
plt.ylabel('VehOdo')
plt.show()

# %%
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(pdf['VehicleAge'], pdf['VehBCost'], c=kmeans.labels_, 
            s=20)
plt.scatter(centers[:, 0], centers[:, 5], s=200, marker='*', c='k')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('VehicleAge')
plt.ylabel('VehBCost')
plt.show()

# %%
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(pdf['VehicleAge'], pdf['WarrantyCost'], c=kmeans.labels_, 
            s=20)
plt.scatter(centers[:, 0], centers[:, 5], s=200, marker='*', c='k')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('VehicleAge')
plt.ylabel('VehBCost')
plt.show()

# %%
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(pdf['VehOdo'], pdf['VehBCost'], c=kmeans.labels_, 
            s=20)
plt.scatter(centers[:, 0], centers[:, 5], s=200, marker='*', c='k')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('VehOdo')
plt.ylabel('VehBCost')
plt.show()

# %%
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(pdf['MMRAcquisitionAuctionAveragePrice'], pdf['Cost/Odometer'], c=kmeans.labels_, 
            s=20)
plt.scatter(centers[:, 0], centers[:, 5], s=200, marker='*', c='k')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('Cost/Odometer')
plt.show()

# %%
plt.figure(figsize=(8, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.xticks(range(0, len(pdf.columns)), pdf.columns, fontsize=7)
plt.legend(fontsize=10)
plt.show()

# %% [markdown]
# Now we can add the laber of the cluster to our database.

# %%
df_kmeans = pd.read_csv("df_DBSCAN_Clustering_forAnalysis1.csv", skipinitialspace=True, sep=',')
df_kmeans
# Out:
#         PurchDate     Model  SubModel  VehYear  RefId  IsBadBuy  Auction  \
# 0      2009-07-28  1500 RAM   EXT CAB     2001  61608         1    ADESA
# 1      2009-07-28  1500 RAM   EXT CAB     2001  61608         1    ADESA
# 2      2009-01-12  1500 RAM  MEGA CAB     2006  33703         0  MANHEIM
# 3      2009-02-25  1500 RAM  MEGA CAB     2006  50261         0  MANHEIM
# 4      2009-02-25  1500 RAM  MEGA CAB     2006  50261         0  MANHEIM
# ...           ...       ...       ...      ...    ...       ...      ...
# 50901  2010-02-18    ZEPHYR     SEDAN     2006  25215         0    OTHER
# 50902  2010-11-23    ZEPHYR     SEDAN     2006   9964         0  MANHEIM
# 50903  2009-03-03    ZEPHYR     SEDAN     2006  32556         0  MANHEIM
# 50904  2009-03-03    ZEPHYR     SEDAN     2006  32556         0  MANHEIM
# 50905  2010-09-22    ZEPHYR     SEDAN     2006  42247         1    OTHER
#
#        VehicleAge     Make Engine  ... VNZIP1 VNST  VehBCost  IsOnlineSale  \
# 0               8    DODGE   5.2L  ...  91752   CA    4315.0             0
# 1               8    DODGE   5.2L  ...  91752   CA    4315.0             0
# 2               3    DODGE   5.7L  ...  34761   FL   11515.0             0
# 3               3    DODGE   5.7L  ...  78219   TX   10835.0             0
# 4               3    DODGE   5.7L  ...  78219   TX   10835.0             0
# ...           ...      ...    ...  ...    ...  ...       ...           ...
# 50901           4  LINCOLN    NaN  ...  80229   CO    8675.0             0
# 50902           4  LINCOLN    NaN  ...  21075   MD   10115.0             0
# 50903           3  LINCOLN    NaN  ...  80022   CO    9215.0             0
# 50904           3  LINCOLN    NaN  ...  80022   CO    9215.0             0
# 50905           4  LINCOLN    NaN  ...  27407   NC    9005.0             0
#
#       WarrantyCost Doors TotalPrice  CostOverOdo  labels_DBSCAN  Cost/Odometer
# 0             1054    4D     5369.0     0.078288              0       0.078288
# 1             1054    4D     5369.0     0.078288              0       0.078288
# 2              983   NaN    12498.0     0.142777              0       0.142777
# 3              920   NaN    11755.0     0.148980              0       0.148980
# 4              920   NaN    11755.0     0.148980              0       0.148980
# ...            ...   ...        ...          ...            ...            ...
# 50901         1373    4D    10048.0     0.105425              0       0.105425
# 50902         1373    4D    11488.0     0.125100              0       0.125100
# 50903         1118    4D    10333.0     0.133597              0       0.133597
# 50904         1118    4D    10333.0     0.133597              0       0.133597
# 50905         1272    4D    10277.0     0.124830              0       0.124830
#
# [50906 rows x 32 columns]

# %% [markdown]
# Prima però i due file devono avere la stessa lunghezza, per questa ragione elimino le righe che presentano gli otliers anche nel file finale, ed elimino "Cost/Odometer" poichè presente due volte con due nomi differenti.

# %%
indexNames = df_kmeans[df_kmeans['labels_DBSCAN'] == -1 ].index
df_kmeans.drop(indexNames , inplace=True)

# %%
df_kmeans['labels_KMeans'] = kmeans.labels_
df_kmeans.drop('Cost/Odometer', axis=1, inplace=True)
df_kmeans
# Out:
#         PurchDate     Model  SubModel  VehYear  RefId  IsBadBuy  Auction  \
# 0      2009-07-28  1500 RAM   EXT CAB     2001  61608         1    ADESA
# 1      2009-07-28  1500 RAM   EXT CAB     2001  61608         1    ADESA
# 2      2009-01-12  1500 RAM  MEGA CAB     2006  33703         0  MANHEIM
# 3      2009-02-25  1500 RAM  MEGA CAB     2006  50261         0  MANHEIM
# 4      2009-02-25  1500 RAM  MEGA CAB     2006  50261         0  MANHEIM
# ...           ...       ...       ...      ...    ...       ...      ...
# 50901  2010-02-18    ZEPHYR     SEDAN     2006  25215         0    OTHER
# 50902  2010-11-23    ZEPHYR     SEDAN     2006   9964         0  MANHEIM
# 50903  2009-03-03    ZEPHYR     SEDAN     2006  32556         0  MANHEIM
# 50904  2009-03-03    ZEPHYR     SEDAN     2006  32556         0  MANHEIM
# 50905  2010-09-22    ZEPHYR     SEDAN     2006  42247         1    OTHER
#
#        VehicleAge     Make Engine  ... VNZIP1 VNST  VehBCost  IsOnlineSale  \
# 0               8    DODGE   5.2L  ...  91752   CA    4315.0             0
# 1               8    DODGE   5.2L  ...  91752   CA    4315.0             0
# 2               3    DODGE   5.7L  ...  34761   FL   11515.0             0
# 3               3    DODGE   5.7L  ...  78219   TX   10835.0             0
# 4               3    DODGE   5.7L  ...  78219   TX   10835.0             0
# ...           ...      ...    ...  ...    ...  ...       ...           ...
# 50901           4  LINCOLN    NaN  ...  80229   CO    8675.0             0
# 50902           4  LINCOLN    NaN  ...  21075   MD   10115.0             0
# 50903           3  LINCOLN    NaN  ...  80022   CO    9215.0             0
# 50904           3  LINCOLN    NaN  ...  80022   CO    9215.0             0
# 50905           4  LINCOLN    NaN  ...  27407   NC    9005.0             0
#
#       WarrantyCost Doors TotalPrice  CostOverOdo  labels_DBSCAN  labels_KMeans
# 0             1054    4D     5369.0     0.078288              0              0
# 1             1054    4D     5369.0     0.078288              0              0
# 2              983   NaN    12498.0     0.142777              0              5
# 3              920   NaN    11755.0     0.148980              0              5
# 4              920   NaN    11755.0     0.148980              0              5
# ...            ...   ...        ...          ...            ...            ...
# 50901         1373    4D    10048.0     0.105425              0              5
# 50902         1373    4D    11488.0     0.125100              0              5
# 50903         1118    4D    10333.0     0.133597              0              5
# 50904         1118    4D    10333.0     0.133597              0              5
# 50905         1272    4D    10277.0     0.124830              0              5
#
# [50850 rows x 32 columns]

# %% [markdown]
# Output

# %%
df_kmeans.to_csv(path_or_buf='df_KMeans.csv' ,index=False)
