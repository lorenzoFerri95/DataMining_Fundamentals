# %% [markdown]
# # Correlazioni e Scatter Plot

# %% [markdown]
# - Correlazioni degli attributi numerici
#
# - Scatter Plot degli attributi numerici

# %% [markdown]
# Importiamo Librerie e DataSet

# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

from collections import defaultdict
from scipy.stats.stats import pearsonr

df = pd.read_csv("Training_MissingValues.csv")

# %% [markdown]
# # Correlezione degli Attributi Numerici

# %% [markdown]
# ** - Correlazione di Pearson **

# %%
df[df.columns.difference(['RefId', 'IsBadBuy', 'IsOnlineSale', 'WheelTypeID',\
                         'BYRNO', 'VNZIP1', 'VehYear'])].corr()
# Out:
#                                    MMRAcquisitionAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.989809
# MMRAcquisitionRetailAveragePrice                            0.904546
# MMRAcquisitonRetailCleanPrice                               0.904017
# MMRCurrentAuctionAveragePrice                               0.957081
# MMRCurrentAuctionCleanPrice                                 0.951029
# MMRCurrentRetailAveragePrice                                0.890480
# MMRCurrentRetailCleanPrice                                  0.889119
# VehBCost                                                    0.828761
# VehOdo                                                     -0.029714
# VehicleAge                                                 -0.599347
# WarrantyCost                                               -0.062992
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                         0.989809
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.895377
# MMRAcquisitonRetailCleanPrice                             0.911503
# MMRCurrentAuctionAveragePrice                             0.944835
# MMRCurrentAuctionCleanPrice                               0.953467
# MMRCurrentRetailAveragePrice                              0.881047
# MMRCurrentRetailCleanPrice                                0.891549
# VehBCost                                                  0.826508
# VehOdo                                                    0.015570
# VehicleAge                                               -0.554130
# WarrantyCost                                             -0.031523
#
#                                    MMRAcquisitionRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                          0.904546
# MMRAcquisitionAuctionCleanPrice                            0.895377
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.989619
# MMRCurrentAuctionAveragePrice                              0.868332
# MMRCurrentAuctionCleanPrice                                0.864969
# MMRCurrentRetailAveragePrice                               0.936613
# MMRCurrentRetailCleanPrice                                 0.928688
# VehBCost                                                   0.788474
# VehOdo                                                     0.019460
# VehicleAge                                                -0.494518
# WarrantyCost                                              -0.064902
#
#                                    MMRAcquisitonRetailCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                       0.904017
# MMRAcquisitionAuctionCleanPrice                         0.911503
# MMRAcquisitionRetailAveragePrice                        0.989619
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.865504
# MMRCurrentAuctionCleanPrice                             0.873859
# MMRCurrentRetailAveragePrice                            0.928815
# MMRCurrentRetailCleanPrice                              0.932162
# VehBCost                                                0.793813
# VehOdo                                                  0.055023
# VehicleAge                                             -0.460930
# WarrantyCost                                           -0.037127
#
#                                    MMRCurrentAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                       0.957081
# MMRAcquisitionAuctionCleanPrice                         0.944835
# MMRAcquisitionRetailAveragePrice                        0.868332
# MMRAcquisitonRetailCleanPrice                           0.865504
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.990021
# MMRCurrentRetailAveragePrice                            0.912116
# MMRCurrentRetailCleanPrice                              0.909169
# VehBCost                                                0.802113
# VehOdo                                                 -0.043128
# VehicleAge                                             -0.601396
# WarrantyCost                                           -0.067549
#
#                                    MMRCurrentAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                     0.951029
# MMRAcquisitionAuctionCleanPrice                       0.953467
# MMRAcquisitionRetailAveragePrice                      0.864969
# MMRAcquisitonRetailCleanPrice                         0.873859
# MMRCurrentAuctionAveragePrice                         0.990021
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.904652
# MMRCurrentRetailCleanPrice                            0.917973
# VehBCost                                              0.801950
# VehOdo                                                0.000483
# VehicleAge                                           -0.559437
# WarrantyCost                                         -0.037427
#
#                                    MMRCurrentRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                      0.890480
# MMRAcquisitionAuctionCleanPrice                        0.881047
# MMRAcquisitionRetailAveragePrice                       0.936613
# MMRAcquisitonRetailCleanPrice                          0.928815
# MMRCurrentAuctionAveragePrice                          0.912116
# MMRCurrentAuctionCleanPrice                            0.904652
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.989375
# VehBCost                                               0.783463
# VehOdo                                                 0.001819
# VehicleAge                                            -0.532194
# WarrantyCost                                          -0.067847
#
#                                    MMRCurrentRetailCleanPrice  VehBCost  \
# MMRAcquisitionAuctionAveragePrice                    0.889119  0.828761
# MMRAcquisitionAuctionCleanPrice                      0.891549  0.826508
# MMRAcquisitionRetailAveragePrice                     0.928688  0.788474
# MMRAcquisitonRetailCleanPrice                        0.932162  0.793813
# MMRCurrentAuctionAveragePrice                        0.909169  0.802113
# MMRCurrentAuctionCleanPrice                          0.917973  0.801950
# MMRCurrentRetailAveragePrice                         0.989375  0.783463
# MMRCurrentRetailCleanPrice                           1.000000  0.787237
# VehBCost                                             0.787237  1.000000
# VehOdo                                               0.036653 -0.068337
# VehicleAge                                          -0.498326 -0.325033
# WarrantyCost                                        -0.040899 -0.041367
#
#                                      VehOdo  VehicleAge  WarrantyCost
# MMRAcquisitionAuctionAveragePrice -0.029714   -0.599347     -0.062992
# MMRAcquisitionAuctionCleanPrice    0.015570   -0.554130     -0.031523
# MMRAcquisitionRetailAveragePrice   0.019460   -0.494518     -0.064902
# MMRAcquisitonRetailCleanPrice      0.055023   -0.460930     -0.037127
# MMRCurrentAuctionAveragePrice     -0.043128   -0.601396     -0.067549
# MMRCurrentAuctionCleanPrice        0.000483   -0.559437     -0.037427
# MMRCurrentRetailAveragePrice       0.001819   -0.532194     -0.067847
# MMRCurrentRetailCleanPrice         0.036653   -0.498326     -0.040899
# VehBCost                          -0.068337   -0.325033     -0.041367
# VehOdo                             1.000000    0.332777      0.408248
# VehicleAge                         0.332777    1.000000      0.271977
# WarrantyCost                       0.408248    0.271977      1.000000

# %% [markdown]
# Gli attributi 'VehOdo', 'VehicleAge', 'WarrantyCost' non hanno correlazioni significative con gli altri attributi, quindi li elimino dalla matrice per semplificare i calcoli.

# %%
df[df.columns.difference(['RefId', 'IsBadBuy', 'IsOnlineSale', 'WheelTypeID',\
                         'BYRNO', 'VNZIP1', 'VehYear', 'WarrantyCost', 'VehicleAge', 'VehOdo'])].corr()
# Out:
#                                    MMRAcquisitionAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.989809
# MMRAcquisitionRetailAveragePrice                            0.904546
# MMRAcquisitonRetailCleanPrice                               0.904017
# MMRCurrentAuctionAveragePrice                               0.957081
# MMRCurrentAuctionCleanPrice                                 0.951029
# MMRCurrentRetailAveragePrice                                0.890480
# MMRCurrentRetailCleanPrice                                  0.889119
# VehBCost                                                    0.828761
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                         0.989809
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.895377
# MMRAcquisitonRetailCleanPrice                             0.911503
# MMRCurrentAuctionAveragePrice                             0.944835
# MMRCurrentAuctionCleanPrice                               0.953467
# MMRCurrentRetailAveragePrice                              0.881047
# MMRCurrentRetailCleanPrice                                0.891549
# VehBCost                                                  0.826508
#
#                                    MMRAcquisitionRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                          0.904546
# MMRAcquisitionAuctionCleanPrice                            0.895377
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.989619
# MMRCurrentAuctionAveragePrice                              0.868332
# MMRCurrentAuctionCleanPrice                                0.864969
# MMRCurrentRetailAveragePrice                               0.936613
# MMRCurrentRetailCleanPrice                                 0.928688
# VehBCost                                                   0.788474
#
#                                    MMRAcquisitonRetailCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                       0.904017
# MMRAcquisitionAuctionCleanPrice                         0.911503
# MMRAcquisitionRetailAveragePrice                        0.989619
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.865504
# MMRCurrentAuctionCleanPrice                             0.873859
# MMRCurrentRetailAveragePrice                            0.928815
# MMRCurrentRetailCleanPrice                              0.932162
# VehBCost                                                0.793813
#
#                                    MMRCurrentAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                       0.957081
# MMRAcquisitionAuctionCleanPrice                         0.944835
# MMRAcquisitionRetailAveragePrice                        0.868332
# MMRAcquisitonRetailCleanPrice                           0.865504
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.990021
# MMRCurrentRetailAveragePrice                            0.912116
# MMRCurrentRetailCleanPrice                              0.909169
# VehBCost                                                0.802113
#
#                                    MMRCurrentAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                     0.951029
# MMRAcquisitionAuctionCleanPrice                       0.953467
# MMRAcquisitionRetailAveragePrice                      0.864969
# MMRAcquisitonRetailCleanPrice                         0.873859
# MMRCurrentAuctionAveragePrice                         0.990021
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.904652
# MMRCurrentRetailCleanPrice                            0.917973
# VehBCost                                              0.801950
#
#                                    MMRCurrentRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                      0.890480
# MMRAcquisitionAuctionCleanPrice                        0.881047
# MMRAcquisitionRetailAveragePrice                       0.936613
# MMRAcquisitonRetailCleanPrice                          0.928815
# MMRCurrentAuctionAveragePrice                          0.912116
# MMRCurrentAuctionCleanPrice                            0.904652
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.989375
# VehBCost                                               0.783463
#
#                                    MMRCurrentRetailCleanPrice  VehBCost
# MMRAcquisitionAuctionAveragePrice                    0.889119  0.828761
# MMRAcquisitionAuctionCleanPrice                      0.891549  0.826508
# MMRAcquisitionRetailAveragePrice                     0.928688  0.788474
# MMRAcquisitonRetailCleanPrice                        0.932162  0.793813
# MMRCurrentAuctionAveragePrice                        0.909169  0.802113
# MMRCurrentAuctionCleanPrice                          0.917973  0.801950
# MMRCurrentRetailAveragePrice                         0.989375  0.783463
# MMRCurrentRetailCleanPrice                           1.000000  0.787237
# VehBCost                                             0.787237  1.000000

# %% [markdown]
# ** - Correlazione di Spearman **

# %%
df[df.columns.difference(['RefId', 'IsBadBuy', 'IsOnlineSale', 'WheelTypeID',\
                         'BYRNO', 'VNZIP1', 'VehYear', 'WarrantyCost', 'VehicleAge', 'VehOdo'])].corr('spearman')
# Out:
#                                    MMRAcquisitionAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.990475
# MMRAcquisitionRetailAveragePrice                            0.894417
# MMRAcquisitonRetailCleanPrice                               0.892213
# MMRCurrentAuctionAveragePrice                               0.957613
# MMRCurrentAuctionCleanPrice                                 0.951927
# MMRCurrentRetailAveragePrice                                0.884434
# MMRCurrentRetailCleanPrice                                  0.881962
# VehBCost                                                    0.845896
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                         0.990475
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.886494
# MMRAcquisitonRetailCleanPrice                             0.899525
# MMRCurrentAuctionAveragePrice                             0.945587
# MMRCurrentAuctionCleanPrice                               0.952974
# MMRCurrentRetailAveragePrice                              0.875679
# MMRCurrentRetailCleanPrice                                0.883895
# VehBCost                                                  0.850652
#
#                                    MMRAcquisitionRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                          0.894417
# MMRAcquisitionAuctionCleanPrice                            0.886494
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.989502
# MMRCurrentAuctionAveragePrice                              0.857630
# MMRCurrentAuctionCleanPrice                                0.855568
# MMRCurrentRetailAveragePrice                               0.931779
# MMRCurrentRetailCleanPrice                                 0.924265
# VehBCost                                                   0.793770
#
#                                    MMRAcquisitonRetailCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                       0.892213
# MMRAcquisitionAuctionCleanPrice                         0.899525
# MMRAcquisitionRetailAveragePrice                        0.989502
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.853260
# MMRCurrentAuctionCleanPrice                             0.861627
# MMRCurrentRetailAveragePrice                            0.923056
# MMRCurrentRetailCleanPrice                              0.926489
# VehBCost                                                0.801505
#
#                                    MMRCurrentAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                       0.957613
# MMRAcquisitionAuctionCleanPrice                         0.945587
# MMRAcquisitionRetailAveragePrice                        0.857630
# MMRAcquisitonRetailCleanPrice                           0.853260
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.990728
# MMRCurrentRetailAveragePrice                            0.904032
# MMRCurrentRetailCleanPrice                              0.900009
# VehBCost                                                0.818660
#
#                                    MMRCurrentAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                     0.951927
# MMRAcquisitionAuctionCleanPrice                       0.952974
# MMRAcquisitionRetailAveragePrice                      0.855568
# MMRAcquisitonRetailCleanPrice                         0.861627
# MMRCurrentAuctionAveragePrice                         0.990728
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.897728
# MMRCurrentRetailCleanPrice                            0.908659
# VehBCost                                              0.824342
#
#                                    MMRCurrentRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                      0.884434
# MMRAcquisitionAuctionCleanPrice                        0.875679
# MMRAcquisitionRetailAveragePrice                       0.931779
# MMRAcquisitonRetailCleanPrice                          0.923056
# MMRCurrentAuctionAveragePrice                          0.904032
# MMRCurrentAuctionCleanPrice                            0.897728
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.989113
# VehBCost                                               0.790702
#
#                                    MMRCurrentRetailCleanPrice  VehBCost
# MMRAcquisitionAuctionAveragePrice                    0.881962  0.845896
# MMRAcquisitionAuctionCleanPrice                      0.883895  0.850652
# MMRAcquisitionRetailAveragePrice                     0.924265  0.793770
# MMRAcquisitonRetailCleanPrice                        0.926489  0.801505
# MMRCurrentAuctionAveragePrice                        0.900009  0.818660
# MMRCurrentAuctionCleanPrice                          0.908659  0.824342
# MMRCurrentRetailAveragePrice                         0.989113  0.790702
# MMRCurrentRetailCleanPrice                           1.000000  0.796774
# VehBCost                                             0.796774  1.000000

# %% [markdown]
# ** - Correlazione di Kendall **

# %%
df[df.columns.difference(['RefId', 'IsBadBuy', 'IsOnlineSale', 'WheelTypeID',\
                         'BYRNO', 'VNZIP1', 'VehYear', 'WarrantyCost', 'VehicleAge', 'VehOdo'])].corr('kendall')
# Out:
#                                    MMRAcquisitionAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.918926
# MMRAcquisitionRetailAveragePrice                            0.735630
# MMRAcquisitonRetailCleanPrice                               0.717855
# MMRCurrentAuctionAveragePrice                               0.841425
# MMRCurrentAuctionCleanPrice                                 0.826679
# MMRCurrentRetailAveragePrice                                0.707591
# MMRCurrentRetailCleanPrice                                  0.703101
# VehBCost                                                    0.650901
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                         0.918926
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.712481
# MMRAcquisitonRetailCleanPrice                             0.742614
# MMRCurrentAuctionAveragePrice                             0.813407
# MMRCurrentAuctionCleanPrice                               0.833064
# MMRCurrentRetailAveragePrice                              0.694015
# MMRCurrentRetailCleanPrice                                0.707206
# VehBCost                                                  0.657138
#
#                                    MMRAcquisitionRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                          0.735630
# MMRAcquisitionAuctionCleanPrice                            0.712481
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.915597
# MMRCurrentAuctionAveragePrice                              0.673050
# MMRCurrentAuctionCleanPrice                                0.669732
# MMRCurrentRetailAveragePrice                               0.798076
# MMRCurrentRetailCleanPrice                                 0.780569
# VehBCost                                                   0.595039
#
#                                    MMRAcquisitonRetailCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                       0.717855
# MMRAcquisitionAuctionCleanPrice                         0.742614
# MMRAcquisitionRetailAveragePrice                        0.915597
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.666433
# MMRCurrentAuctionCleanPrice                             0.679116
# MMRCurrentRetailAveragePrice                            0.778067
# MMRCurrentRetailCleanPrice                              0.788332
# VehBCost                                                0.603179
#
#                                    MMRCurrentAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                       0.841425
# MMRAcquisitionAuctionCleanPrice                         0.813407
# MMRAcquisitionRetailAveragePrice                        0.673050
# MMRAcquisitonRetailCleanPrice                           0.666433
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.919909
# MMRCurrentRetailAveragePrice                            0.747196
# MMRCurrentRetailCleanPrice                              0.728614
# VehBCost                                                0.621854
#
#                                    MMRCurrentAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                     0.826679
# MMRAcquisitionAuctionCleanPrice                       0.833064
# MMRAcquisitionRetailAveragePrice                      0.669732
# MMRAcquisitonRetailCleanPrice                         0.679116
# MMRCurrentAuctionAveragePrice                         0.919909
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.730204
# MMRCurrentRetailCleanPrice                            0.752743
# VehBCost                                              0.628911
#
#                                    MMRCurrentRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                      0.707591
# MMRAcquisitionAuctionCleanPrice                        0.694015
# MMRAcquisitionRetailAveragePrice                       0.798076
# MMRAcquisitonRetailCleanPrice                          0.778067
# MMRCurrentAuctionAveragePrice                          0.747196
# MMRCurrentAuctionCleanPrice                            0.730204
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.913717
# VehBCost                                               0.592810
#
#                                    MMRCurrentRetailCleanPrice  VehBCost
# MMRAcquisitionAuctionAveragePrice                    0.703101  0.650901
# MMRAcquisitionAuctionCleanPrice                      0.707206  0.657138
# MMRAcquisitionRetailAveragePrice                     0.780569  0.595039
# MMRAcquisitonRetailCleanPrice                        0.788332  0.603179
# MMRCurrentAuctionAveragePrice                        0.728614  0.621854
# MMRCurrentAuctionCleanPrice                          0.752743  0.628911
# MMRCurrentRetailAveragePrice                         0.913717  0.592810
# MMRCurrentRetailCleanPrice                           1.000000  0.599923
# VehBCost                                             0.599923  1.000000

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# Scatter Plot di tutte le coppie di attributi (Scatter Matrix)
#
# Da questo grafico possiamo scegliere quali combinazioni di attributi sono più interessanti da analizzare graficamente

# %%
pd.plotting.scatter_matrix(df[['MMRAcquisitionAuctionAveragePrice', 'VehBCost', 'VehOdo', 'VehicleAge', 'WarrantyCost']], 
                           figsize=(15, 10))
plt.show()

# %%
pd.plotting.scatter_matrix(df[['MMRAcquisitionAuctionAveragePrice', 'MMRCurrentAuctionCleanPrice',
                               'MMRCurrentRetailAveragePrice', 'MMRAcquisitonRetailCleanPrice']], figsize=(15, 10))
plt.show()

# %%
pd.plotting.scatter_matrix(df[['MMRCurrentAuctionAveragePrice', 'MMRAcquisitionAuctionCleanPrice',
                               'MMRAcquisitionRetailAveragePrice', 'MMRCurrentRetailCleanPrice']], figsize=(15, 10))
plt.show()

# %% [markdown]
# *** - MMRAcquisitionAuctionAveragePrice vs MMRAcquisitionAuctionCleanPrice ***

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionCleanPrice'], color='r', label='NotBadBuy', s=15)
plt.scatter(df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionCleanPrice'], color='g', marker='*' ,label='BadBuy', s=15)
plt.title('MMRAvgPrice vs MMRCleanPrice Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('MMRAcquisitionAuctionCleanPrice')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionCleanPrice'], color='r', label='NotBadBuy', s=15, alpha = 0.1)
plt.scatter(df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionCleanPrice'], color='g', marker='*' ,label='BadBuy', s=15, alpha = 0.1)
plt.title('MMRAvgPrice vs MMRCleanPrice Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('MMRAcquisitionAuctionCleanPrice')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionCleanPrice'], color='r', label='NotBadBuy', s=15, alpha = 0.01)
plt.scatter(df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionCleanPrice'], color='g', marker='*' ,label='BadBuy', s=15, alpha = 0.01)
plt.title('MMRAvgPrice vs MMRCleanPrice Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('MMRAcquisitionAuctionCleanPrice')
plt.legend()
plt.show()

# %%
x = df['MMRAcquisitionAuctionAveragePrice'].values
y = df['MMRAcquisitionAuctionCleanPrice'].values

xy = np.vstack([x,y])
z = stats.gaussian_kde(xy)(xy)

idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

plt.figure(figsize=(10, 5))
fig, ax = plt.subplots()
ax.scatter(x, y, c=z, s=10, edgecolor='')
plt.title('MMRAvgPrice vs MMRCleanPrice Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('MMRAcquisitionAuctionCleanPrice')
plt.show()

# %% [markdown]
# *** - MMRAcquisitionAuctionAveragePrice vs VehBCost ***

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionAveragePrice'],
            df[df['IsBadBuy'] == 0]['VehBCost'], color='r', label='NotBadBuy', s=15)
plt.scatter(df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 1]['VehBCost'], color='g', marker='*' ,label='BadBuy', s=15)
plt.title('MMRAvgPrice vs VehBCost Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('VehBCost')
plt.legend()
plt.tick_params(axis='both', pad=10, labelsize=10)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionAveragePrice'],
            df[df['IsBadBuy'] == 0]['VehBCost'], color='r', label='NotBadBuy', s=15, alpha = 0.1)
plt.scatter(df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 1]['VehBCost'], color='g', marker='*' ,label='BadBuy', s=15, alpha = 0.1)
plt.title('MMRAvgPrice vs VehBCost Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('VehBCost')
plt.legend()
plt.tick_params(axis='both', pad=10, labelsize=10)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionAveragePrice'],
            df[df['IsBadBuy'] == 0]['VehBCost'], color='r', label='NotBadBuy', s=15, alpha = 0.01)
plt.scatter(df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 1]['VehBCost'], color='g', marker='*' ,label='BadBuy', s=15, alpha = 0.01)
plt.title('MMRAvgPrice vs VehBCost Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('VehBCost')
plt.legend()
plt.tick_params(axis='both', pad=10, labelsize=10)
plt.show()

# %%
x = df['MMRAcquisitionAuctionAveragePrice'].values
y = df['VehBCost'].values

xy = np.vstack([x,y])
z = stats.gaussian_kde(xy)(xy)

idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

plt.figure(figsize=(10, 5))
fig, ax = plt.subplots()
ax.scatter(x, y, c=z, s=10, edgecolor='')
plt.title('MMRAvgPrice vs VehBCost Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('VehBCost')
plt.show()

# %% [markdown]
# *** - MMRAcquisitionAuctionAveragePrice vs VehOdo ***

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 0]['VehOdo'], color='r', label='NotBadBuy', s=15)
plt.scatter(df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 1]['VehOdo'], color='g', marker='*' ,label='BadBuy', s=15)
plt.title('MMRAvgPrice vs VehOdo Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('VehOdo')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 0]['VehOdo'], color='r', label='NotBadBuy', s=15, alpha = 0.1)
plt.scatter(df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 1]['VehOdo'], color='g', marker='*' ,label='BadBuy', s=15, alpha = 0.1)
plt.title('MMRAvgPrice vs VehOdo Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('VehOdo')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 0]['VehOdo'], color='r', label='NotBadBuy', s=15, alpha = 0.01)
plt.scatter(df[df['IsBadBuy'] == 1]['MMRAcquisitionAuctionAveragePrice'], 
            df[df['IsBadBuy'] == 1]['VehOdo'], color='g', marker='*' ,label='BadBuy', s=15, alpha = 0.01)
plt.title('MMRAvgPrice vs VehOdo Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('VehOdo')
plt.legend()
plt.show()

# %%
x = df['MMRAcquisitionAuctionAveragePrice'].values
y = df['VehOdo'].values

xy = np.vstack([x,y])
z = stats.gaussian_kde(xy)(xy)

idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

plt.figure(figsize=(10, 5))
fig, ax = plt.subplots()
ax.scatter(x, y, c=z, s=10, edgecolor='')
plt.title('MMRAvgPrice vs VehOdo Scatter Plot')
plt.xlabel('MMRAcquisitionAuctionAveragePrice')
plt.ylabel('VehOdo')
plt.show()

# %% [markdown]
# *** - VehOdo vs VehBCost ***

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['VehOdo'], 
            df[df['IsBadBuy'] == 0]['VehBCost'], color='r', label='NotBadBuy', s=15)
plt.scatter(df[df['IsBadBuy'] == 1]['VehOdo'], 
            df[df['IsBadBuy'] == 1]['VehBCost'], color='g', marker='*' ,label='BadBuy', s=15)
plt.title('VehOdo vs VehBCost Scatter Plot')
plt.xlabel('VehOdo')
plt.ylabel('VehBCost')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['VehOdo'], 
            df[df['IsBadBuy'] == 0]['VehBCost'], color='r', label='NotBadBuy', s=15, alpha = 0.1)
plt.scatter(df[df['IsBadBuy'] == 1]['VehOdo'], 
            df[df['IsBadBuy'] == 1]['VehBCost'], color='g', marker='*' ,label='BadBuy', s=15, alpha = 0.1)
plt.title('VehOdo vs VehBCost Scatter Plot')
plt.xlabel('VehOdo')
plt.ylabel('VehBCost')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df[df['IsBadBuy'] == 0]['VehOdo'], 
            df[df['IsBadBuy'] == 0]['VehBCost'], color='r', label='NotBadBuy', s=15, alpha = 0.01)
plt.scatter(df[df['IsBadBuy'] == 1]['VehOdo'], 
            df[df['IsBadBuy'] == 1]['VehBCost'], color='g', marker='*' ,label='BadBuy', s=15, alpha = 0.01)
plt.title('VehOdo vs VehBCost Scatter Plot')
plt.xlabel('VehOdo')
plt.ylabel('VehBCost')
plt.legend()
plt.show()

# %%
x = df['VehOdo'].values
y = df['VehBCost'].values

xy = np.vstack([x,y])
z = stats.gaussian_kde(xy)(xy)

idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

plt.figure(figsize=(10, 5))
fig, ax = plt.subplots()
ax.scatter(x, y, c=z, s=10, edgecolor='')
plt.title('VehOdo vs VehBCost Scatter Plot')
plt.xlabel('VehOdo')
plt.ylabel('VehBCost')
plt.show()

# %% [markdown]
# ** Eliminazione degli Attributi molto correlati **

# %%
del df['MMRAcquisitionAuctionCleanPrice']
del df['MMRAcquisitonRetailCleanPrice']
del df['MMRCurrentAuctionCleanPrice']
del df['MMRCurrentRetailCleanPrice']
del df['MMRAcquisitionRetailAveragePrice']
del df['MMRCurrentAuctionAveragePrice']
del df['MMRCurrentRetailAveragePrice']

# %% [markdown]
# # File della Data Understanding generale in Output

# %%
df.to_csv(path_or_buf='Training_DU.csv' ,index=False)
