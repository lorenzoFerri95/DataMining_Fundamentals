# %% [markdown]
# # Trasformazioni
#
# prepariamo il Dataset per le analisi successive: Clustering; Classification; Association.
#
# 1) Clustering:
#
# abbiamo bisogno dei soli attributi numerici standardizzati. Inoltre il dataset è troppo grosso, quindi operiamo un Sample su di esso condizionato a raggruppamenti categorici
#
# 2) Classification:
#
#
# 3) Association:

# %% [markdown]
# ** Import DataSet e Librerie Data Understanding **

# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

from collections import defaultdict
from scipy.stats.stats import pearsonr

df = pd.read_csv('Training_DU.csv')

# %%
df_Clustering = df.copy()
df_Classification = df.copy()
df_Association = df.copy()

# %%
del df

# %% [markdown]
# ## 1) Tasformazioni per il Clustering

# %%
df_Clustering.count()
# Out:
# PurchDate                            50906
# Model                                50906
# SubModel                             50906
# VehYear                              50906
# RefId                                50906
# IsBadBuy                             50906
# Auction                              50906
# VehicleAge                           50906
# Make                                 50906
# Engine                               33078
# Trim                                 50906
# Transmission                         50906
# WheelTypeID                          50906
# VehOdo                               50906
# Nationality                          50906
# Size                                 50906
# TopThreeAmericanName                 50906
# MMRAcquisitionAuctionAveragePrice    50906
# BYRNO                                50906
# VNZIP1                               50906
# VNST                                 50906
# VehBCost                             50906
# IsOnlineSale                         50906
# WarrantyCost                         50906
# Doors                                44497
# dtype: int64

# %%
df_Clustering['Model'].nunique()
# Out:
# 261

# %%
df_Clustering['SubModel'].nunique()
# Out:
# 38

# %%
df_Clustering['VehYear'].nunique()
# Out:
# 10

# %% [markdown]
# ** Trasformazioni variabili categoriche in numeriche **

# %% [markdown]
# trasformiamo WheelTypeID,Transmission,Nationality in variabili numeriche per usarle anche nella Cluster Analysis

# %%
#1 TRANSMISSION
#Clustering_df['Transmission'].unique()

# %%
#transm = sorted(Clustering_df['Transmission'].unique())
#transm_mapping = dict(zip(transm, range(0, len(transm) + 1)))
#transm_mapping

# %%
#Clustering_df['TransmissionID'] = Clustering_df['Transmission'].map(transm_mapping).astype(int)
#Clustering_df[['Transmission', 'TransmissionID']].head()

# %%
#2 NATIONALITY
#Clustering_df['Nationality'].unique()

# %%
#nation = sorted(Clustering_df['Nationality'].unique())
#nation_mapping = dict(zip(nation, range(0, len(nation) + 1)))
#nation_mapping

# %%
#Clustering_df['NationalityID'] = Clustering_df['Nationality'].map(nation_mapping).astype(int)
#Clustering_df[['Nationality', 'NationalityID']].head()

# %% [markdown]
# ** nuove variabili **

# %%
df_Clustering['CostOverOdo'] = df_Clustering['VehBCost'] / df_Clustering['VehOdo']

# %%
df_Clustering['TotalPrice'] = df_Clustering['VehBCost'] + df_Clustering['WarrantyCost']

# %%
df_Clustering.head()
# Out:
#     PurchDate     Model  SubModel  VehYear  RefId  IsBadBuy  Auction  \
# 0  2009-01-04  1500 RAM  QUAD CAB     2002  62472         0    ADESA
# 1  2009-01-04  1500 RAM  QUAD CAB     2003  16342         0  MANHEIM
# 2  2009-01-04  1500 RAM  QUAD CAB     2005  16344         0  MANHEIM
# 3  2009-01-04       300     SEDAN     2006  62463         0    ADESA
# 4  2009-01-04       300     SEDAN     2006  20574         0  MANHEIM
#
#    VehicleAge      Make    Engine     ...      \
# 0           7     DODGE      5.9L     ...
# 1           6     DODGE      5.7L     ...
# 2           4     DODGE      5.7L     ...
# 3           3  CHRYSLER  2.7L MPI     ...
# 4           3  CHRYSLER  2.7L MPI     ...
#
#   MMRAcquisitionAuctionAveragePrice  BYRNO  VNZIP1  VNST VehBCost  \
# 0                            5872.0  20234   85226    AZ   7940.0
# 1                            7648.0  19619   32824    FL   9400.0
# 2                           10306.0  19619   32824    FL  10000.0
# 3                            9459.0  20234   85226    AZ   9505.0
# 4                            9459.0  20833   75236    TX  10050.0
#
#   IsOnlineSale WarrantyCost  Doors  CostOverOdo  TotalPrice
# 0            0         1125    NaN     0.127634      9065.0
# 1            0         1220    NaN     0.117610     10620.0
# 2            0          920    NaN     0.126894     10920.0
# 3            0         1389     4D     0.132707     10894.0
# 4            0         1215     4D     0.156352     11265.0
#
# [5 rows x 27 columns]

# %%
df_Clustering[df_Clustering.columns.difference(['RefId', 'TopThreeAmericanName', 'IsBadBuy', 'PurchDate', 'Auction', 'Make', 'Engine', 'Trim',\
                                                'Size','BYRNO', 'VNZIP1', 'VNST', 'IsOnlineSale', 'Model', 'SubModel', 'Doors', 'Nationality',\
                                                'Transmission','Model','SubModel','MMRAcquisitionAuctionAveragePrice','MMRAcquisitionRetailAveragePrice',\
                                               'MMRCurrentAuctionAveragePrice','MMRCurrentRetailAveragePrice','MMRCurrentRetailAveragePrice',\
                                               'VehYear', 'VehicleAge','WheelTypeID'])].corr()
# Out:
#               CostOverOdo  TotalPrice  VehBCost    VehOdo  WarrantyCost
# CostOverOdo      1.000000    0.543756  0.654875 -0.618816     -0.249602
# TotalPrice       0.543756    1.000000  0.943251  0.070288      0.292776
# VehBCost         0.654875    0.943251  1.000000 -0.068337     -0.041367
# VehOdo          -0.618816    0.070288 -0.068337  1.000000      0.408248
# WarrantyCost    -0.249602    0.292776 -0.041367  0.408248      1.000000

# %%
del df_Clustering['TotalPrice']

# %% [markdown]
# ** Operiamo un Sample sul DataSet condizionato a raggruppamenti categorici **

# %%
def Sample_df(x):
    return x.sample(frac=1, replace=True, random_state=1)

# %%
df_Clustering = df_Clustering.groupby([df_Clustering['Model'], df_Clustering['SubModel'],
                                       df_Clustering['VehYear']]).apply(Sample_df)

# %%
df_Clustering.count()
# Out:
# PurchDate                            50906
# Model                                50906
# SubModel                             50906
# VehYear                              50906
# RefId                                50906
# IsBadBuy                             50906
# Auction                              50906
# VehicleAge                           50906
# Make                                 50906
# Engine                               33676
# Trim                                 50906
# Transmission                         50906
# WheelTypeID                          50906
# VehOdo                               50906
# Nationality                          50906
# Size                                 50906
# TopThreeAmericanName                 50906
# MMRAcquisitionAuctionAveragePrice    50906
# BYRNO                                50906
# VNZIP1                               50906
# VNST                                 50906
# VehBCost                             50906
# IsOnlineSale                         50906
# WarrantyCost                         50906
# Doors                                44510
# CostOverOdo                          50906
# dtype: int64

# %%
df_Clustering['Model'].nunique()
# Out:
# 261

# %%
df_Clustering['SubModel'].nunique()
# Out:
# 38

# %%
df_Clustering['VehYear'].nunique()
# Out:
# 10

# %% [markdown]
# Salviamo il Dataframe attuale in una variabile per esportarlo in un file csv: <br>
# ci servirà per ricostruire il dataset finale delle analisi di Clustering (con tutti i valori originali del sample in esame e le label dei cluster in fondo).

# %%
df_Clustering_forResultsAnalysis = df_Clustering.copy()
df_Clustering_forResultsAnalysis
# Out:
#                                   PurchDate     Model  SubModel  VehYear  \
# Model    SubModel VehYear
# 1500 RAM EXT CAB  2001    13133  2009-07-28  1500 RAM   EXT CAB     2001
#                           13133  2009-07-28  1500 RAM   EXT CAB     2001
#          MEGA CAB 2006    3440   2009-02-25  1500 RAM  MEGA CAB     2006
#                           556    2009-01-12  1500 RAM  MEGA CAB     2006
#                           556    2009-01-12  1500 RAM  MEGA CAB     2006
#          QUAD CAB 2002    49681  2010-12-08  1500 RAM  QUAD CAB     2002
#                           13562  2009-07-31  1500 RAM  QUAD CAB     2002
#                           9794   2009-05-28  1500 RAM  QUAD CAB     2002
#                           11263  2009-06-25  1500 RAM  QUAD CAB     2002
#                           12015  2009-07-10  1500 RAM  QUAD CAB     2002
#                           5304   2009-03-25  1500 RAM  QUAD CAB     2002
#                           22995  2009-12-08  1500 RAM  QUAD CAB     2002
#                           0      2009-01-04  1500 RAM  QUAD CAB     2002
#                           24572  2010-01-07  1500 RAM  QUAD CAB     2002
#                           996    2009-01-20  1500 RAM  QUAD CAB     2002
#                           13562  2009-07-31  1500 RAM  QUAD CAB     2002
#                           7900   2009-04-30  1500 RAM  QUAD CAB     2002
#                           7772   2009-04-29  1500 RAM  QUAD CAB     2002
#                           32885  2010-04-30  1500 RAM  QUAD CAB     2002
#                           28815  2010-03-03  1500 RAM  QUAD CAB     2002
#                           49681  2010-12-08  1500 RAM  QUAD CAB     2002
#                           26945  2010-02-07  1500 RAM  QUAD CAB     2002
#                           28815  2010-03-03  1500 RAM  QUAD CAB     2002
#                           12015  2009-07-10  1500 RAM  QUAD CAB     2002
#                           35963  2010-06-16  1500 RAM  QUAD CAB     2002
#                           36859  2010-06-29  1500 RAM  QUAD CAB     2002
#                           20400  2009-10-28  1500 RAM  QUAD CAB     2002
#                           2666   2009-02-17  1500 RAM  QUAD CAB     2002
#                           30346  2010-03-25  1500 RAM  QUAD CAB     2002
#                           30346  2010-03-25  1500 RAM  QUAD CAB     2002
# ...                                     ...       ...       ...      ...
# YUKON XL UTILITY  2003    790    2009-01-13  YUKON XL   UTILITY     2003
#                           16959  2009-09-16  YUKON XL   UTILITY     2003
#                           5113   2009-03-19  YUKON XL   UTILITY     2003
#                           18106  2009-09-30  YUKON XL   UTILITY     2003
#                           3676   2009-02-25  YUKON XL   UTILITY     2003
#                           40000  2010-08-06  YUKON XL   UTILITY     2003
#                           41195  2010-08-24  YUKON XL   UTILITY     2003
#                           3031   2009-02-18  YUKON XL   UTILITY     2003
#                           40000  2010-08-06  YUKON XL   UTILITY     2003
#                           41195  2010-08-24  YUKON XL   UTILITY     2003
#                           12391  2009-07-14  YUKON XL   UTILITY     2003
#                   2004    39392  2010-07-28  YUKON XL   UTILITY     2004
#                           23912  2009-12-18  YUKON XL   UTILITY     2004
#                           26144  2010-01-26  YUKON XL   UTILITY     2004
#                           48665   9964         0  MANHEIM           4
#                           44262  69957         0    ADESA           4
#                           44933  64639         0    ADESA           4
#                           48665   9964         0  MANHEIM           4
#                           27892  25215         0    OTHER           4
#                           4128   32556         0  MANHEIM           3
#                           4128   32556         0  MANHEIM           3
#                           6852   33398         0  MANHEIM           3
#                           43333  42247         1    OTHER           4
#                           38256  70031         0    ADESA           4
#                           44933  64639         0    ADESA           4
#
#                                     Make    Engine     ...       \
# Model    SubModel VehYear                              ...
# 1500 RAM EXT CAB  2001    13133    DODGE      5.2L     ...
#                           13133    DODGE      5.2L     ...
#          MEGA CAB 2006    3440     DODGE      5.7L     ...
#                           556      DODGE      5.7L     ...
#                           556      DODGE      5.7L     ...
#          QUAD CAB 2002    49681    DODGE      4.7L     ...
#                           13562    DODGE      5.9L     ...
#                           9794     DODGE      4.7L     ...
#                           11263    DODGE      4.7L     ...
#                           12015    DODGE      4.7L     ...
#                           5304     DODGE      4.7L     ...
#                           22995    DODGE      5.9L     ...
#                           0        DODGE      5.9L     ...
#                           24572    DODGE      5.9L     ...
#                           996      DODGE      4.7L     ...
#                           13562    DODGE      5.9L     ...
#                           7900     DODGE      4.7L     ...
#                           7772     DODGE      5.9L     ...
#                           32885    DODGE      4.7L     ...
#                           28815    DODGE      4.7L     ...
#                           49681    DODGE      4.7L     ...
#                           26945    DODGE      5.9L     ...
#                           28815    DODGE      4.7L     ...
#                           12015    DODGE      4.7L     ...
#                           35963    DODGE      5.9L     ...
#                           36859    DODGE      4.7L     ...
#                           20400    DODGE      4.7L     ...
#                           2666     DODGE      4.7L     ...
#                           30346    DODGE      4.7L     ...
#                           30346    DODGE      4.7L     ...
# ...                                  ...       ...     ...
# YUKON XL UTILITY  2003    790        GMC      5.0L     ...
#                           16959      GMC      5.0L     ...
#                           5113       GMC      5.0L     ...
#                           18106      GMC      5.0L     ...
#                           3676       GMC      5.0L     ...
#                           40000      GMC      5.3L     ...
#                           41195      GMC      5.3L     ...
#                           3031       GMC      5.0L     ...
#                           40000      GMC      5.3L     ...
#                           41195      GMC      5.3L     ...
#                           12391      GMC      5.0L     ...
#                   2004    39392      GMC      5.3L     ...
#                           23912      GMC      5.3L     ...
#                           26144      GMC      5.3L     ...
#                           791        GMC      5.3L     ...
#                           5572       GMC      5.3L     ...
#                           23912      GMC      5.3L     ...
#                   2005    1339       GMC      5.3L     ...
# ZEPHYR   SEDAN    2006    27892  LINCOLN       NaN     ...
#                           48665  LINCOLN       NaN     ...
#                           44262  LINCOLN       NaN     ...
#                           44933  LINCOLN       NaN     ...
#                           48665  LINCOLN       NaN     ...
#                           27892  LINCOLN       NaN     ...
#                           4128   LINCOLN       NaN     ...
#                           4128   LINCOLN       NaN     ...
#                           6852   LINCOLN  3.0L SFI     ...
#                           43333  LINCOLN       NaN     ...
#                           38256  LINCOLN       NaN     ...
#                           44933  LINCOLN       NaN     ...
#
#                                 TopThreeAmericanName  \
# Model    SubModel VehYear
# 1500 RAM EXT CAB  2001    13
# Model    SubModel VehYear
# 1500 RAM EXT CAB  2001    13133          1054     4D     0.078288
#                           13133          1054     4D     0.078288
#          MEGA CAB 2006    3440            920    NaN     0.148980
#                           556             983    NaN     0.142777
#                           556             983    NaN     0.142777
#          QUAD CAB 2002    49681          1283    NaN     0.103773
#                           13562          1054    NaN     0.110626
#                           9794           1283    NaN     0.103236
#                           11263          1220    NaN     0.109116
#                           12015          1220    NaN     0.097849
#                           5304           1283    NaN     0.092196
#                           22995          1634    NaN     0.225183
#                           0              1125    NaN     0.127634
#                           24572          1634    NaN     0.188036
#                           996            1125    NaN     0.123398
#                           13562          1054    NaN     0.110626
#                           7900           1353    NaN     0.059172
#                           7772           1220    NaN     0.114093
#                           32885          1220    NaN     0.114330
#                           28815          2193    NaN     0.120143
#                           49681          1283    NaN     0.103773
#                           26945          1283    NaN     0.106171
#                           28815          2193    NaN     0.120143
#                           12015          1220    NaN     0.097849
#                           35963          1220    NaN     0.117188
#                           36859          1220    NaN     0.131066
#                           20400          1283    NaN     0.111763
#                           2666           1220    NaN     0.113247
#                           30346          1283    NaN     0.106848
#                           30346          1283    NaN     0.106848
# ...                                       ...    ...          ...
# YUKON XL UTILITY  2003    790            1711     4D     0.114063
#                           16959          1923     4D     0.138269
#                           5113           1923     4D     0.138290
#                           18106          2063     4D     0.127568
#                           3676           2063     4D     0.103515
#                           40000          2218     4D     0.104886
#                           41195          2063     4D     0.123711
#                           3031           1923     4D     0.132075
#                           40000          2218     4D     0.104886
#                           41195          2063     4D     0.123711
#                           12391          1923     4D     0.136552
#                   2004    39392          1763     4D     0.125602
#                           23912          1411     4D     0.171353
#                           26144          1623     4D     0.142143
#                           791            1251     4D     0.176684
#                           5572           1763     4D     0.135948
#                           23912          1411     4D     0.171353
#                   2005    1339           1623     4D     0.144603
# ZEPHYR   SEDAN    2006    27892          1373     4D     0.105425
#                           48665          1373     4D     0.125100
#                           44262          1373     4D     0.109790
#                           44933          1272     4D     0.113031
#                           48665          1373     4D     0.125100
#                           27892          1373     4D     0.105425
#                           4128           1118     4D     0.133597
#                           4128           1118     4D     0.133597
#                           6852           1118     4D     0.150354
#                           43333          1272     4D     0.124830
#                           38256          1272     4D     0.121686
#                           44933          1272     4D     0.113031
#
# [50906 rows x 26 columns]

# %% [markdown]
# ** Eliminazione attributi categorici **

# %%
df_Clustering.dtypes
# Out:
# PurchDate                             object
# Model                                 object
# SubModel                              object
# VehYear                                int64
# RefId                                  int64
# IsBadBuy                               int64
# Auction                               object
# VehicleAge                             int64
# Make                                  object
# Engine                                object
# Trim                                  object
# Transmission                          object
# WheelTypeID                          float64
# VehOdo                                 int64
# Nationality                           object
# Size                                  object
# TopThreeAmericanName                  object
# MMRAcquisitionAuctionAveragePrice    float64
# BYRNO                                  int64
# VNZIP1                                 int64
# VNST                                  object
# VehBCost                             float64
# IsOnlineSale                           int64
# WarrantyCost                           int64
# Doors                                 object
# CostOverOdo                          float64
# dtype: object

# %%
col_toDrop = ['VehYear', 'RefId', 'TopThreeAmericanName', 'IsBadBuy', 'PurchDate', 'Auction', 'Make', 'Engine',
              'WheelTypeID', 'Trim', 'Size', 'BYRNO', 'VNZIP1', 'VNST', 'IsOnlineSale', 'Model', 'SubModel', 'Doors',
              'Nationality', 'Transmission']

df_Clustering = df_Clustering.drop(col_toDrop, axis=1)
df_Clustering
# Out:
#                                  VehicleAge  VehOdo  \
# Model    SubModel VehYear
# 1500 RAM EXT CAB  2001    13
#                   2005    1339                              8601.0   10410.0
# ZEPHYR   SEDAN    2006    27892                            12341.0    8675.0
#                           48665                            10120.0   10115.0
#                           44262                            12495.0    9005.0
#                           44933                            10289.0    8315.0
#                           48665                            10120.0   10115.0
#                           27892                            12341.0    8675.0
#                           4128                             13765.0    9215.0
#                           4128                             13765.0    9215.0
#                           6852                             14443.0   10265.0
#                           43333                            10184.0    9005.0
#                           38256                            12532.0    8615.0
#                           44933                            10289.0    8315.0
#
#                                  WarrantyCost  CostOverOdo
# Model    SubModel VehYear
# 1500 RAM EXT CAB  2001    13133          1054     0.078288
#                           13133          1054     0.078288
#          MEGA CAB 2006    3440            920     0.148980
#                           556             983     0.142777
#                           556             983     0.142777
#          QUAD CAB 2002    49681          1283     0.103773
#                           13562          1054     0.110626
#                           9794           1283     0.103236
#                           11263          1220     0.109116
#                           12015          1220     0.097849
#                           5304           1283     0.092196
#                           22995          1634     0.225183
#                           0              1125     0.127634
#                           24572          1634     0.188036
#                           996            1125     0.123398
#                           13562          1054     0.110626
#                           7900           1353     0.059172
#                           7772           1220     0.114093
#                           32885          1220     0.114330
#                           28815          2193     0.120143
#                           49681          1283     0.103773
#                           26945          1283     0.106171
#                           28815          2193     0.120143
#                           12015          1220     0.097849
#                           35963          1220     0.117188
#                           36859          1220     0.131066
#                           20400          1283     0.111763
#                           2666           1220     0.113247
#                           30346          1283     0.106848
#                           30346          1283     0.106848
# ...                                       ...          ...
# YUKON XL UTILITY  2003    790            1711     0.114063
#                           16959          1923     0.138269
#                           5113           1923     0.138290
#                           18106          2063     0.127568
#                           3676           2063     0.103515
#                           40000          2218     0.104886
#                           41195          2063     0.123711
#                           3031           1923     0.132075
#                           40000          2218     0.104886
#                           41195          2063     0.123711
#                           12391          1923     0.136552
#                   2004    39392          1763     0.125602
#                           23912          1411     0.171353
#                           26144          1623     0.142143
#                           791            1251     0.176684
#                           5572           1763     0.135948
#                           23912          1411     0.171353
#                   2005    1339           1623     0.144603
# ZEPHYR   SEDAN    2006    27892          1373     0.105425
#                           48665          1373     0.125100
#                           44262          1373     0.109790
#                           44933          1272     0.113031
#                           48665          1373     0.125100
#                           27892          1373     0.105425
#                           4128           1118     0.133597
#                           4128           1118     0.133597
#                           6852           1118     0.150354
#                           43333          1272     0.124830
#                           38256          1272     0.121686
#                           44933          1272     0.113031
#
# [50906 rows x 6 columns]

# %% [markdown]
# ** Scaling **

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()

# %%
scaler.fit(df_Clustering)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
col_toScale = df_Clustering.columns

df_Clustering = scaler.transform(df_Clustering)
df_Clustering = pd.DataFrame(df_Clustering, columns = col_toScale)
df_Clustering
# Out:
#        VehicleAge    VehOdo  MMRAcquisitionAuctionAveragePrice  VehBCost  \
# 0        2.192212 -1.100717                          -1.225996 -1.325668
# 1        2.192212 -1.100717                          -1.225996 -1.325668
# 2       -0.675803  0.102976                           2.611267  2.338646
# 3       -0.675803  0.644436                           2.963774  2.720813
# 4       -0.675803  0.644436                           2.963774  2.720813
# 5        2.192212  1.132310                          -0.355535  1.369176
# 6        1.618609 -0.879745                          -0.217940 -0.122964
# 7          0.022553     0.092554
# 8         -0.080092     0.227004
# 9         -0.080092    -0.030593
# 10         0.022553    -0.159850
# 11         0.594432     2.880767
# 12        -0.234874     0.650408
# 13         0.594432     2.031445
# 14        -0.234874     0.553549
# 15        -0.350554     0.261520
# 16         0.136603    -0.914911
# 17        -0.080092     0.340806
# 18        -0.080092     0.346225
# 19         1.505202     0.479130
# 20         0.022553     0.104837
# 21         0.022553     0.159682
# 22         1.505202     0.479130
# 23        -0.080092    -0.030593
# 24        -0.080092     0.411553
# 25        -0.080092     0.728875
# 26         0.022553     0.287521
# 27        -0.080092     0.321461
# 28         0.022553     0.175156
# 29         0.022553     0.175156
# ...             ...          ...
# 50876      0.719887     0.340119
# 50877      1.065295     0.893561
# 50878      1.065295     0.894047
# 50879      1.293395     0.648884
# 50880      1.293395     0.098948
# 50881      1.545934     0.130301
# 50882      1.293395     0.560717
# 50883      1.065295     0.751952
# 50884      1.545934     0.130301
# 50885      1.293395     0.560717
# 50886      1.065295     0.854310
# 50887      0.804609     0.603950
# 50888      0.231101     1.650003
# 50889      0.576510     0.982130
# 50890     -0.029584     1.771883
# 50891      0.804609     0.840483
# 50892      0.231101     1.650003
# 50893      0.576510     1.038392
# 50894      0.169188     0.142614
# 50895      0.169188     0.592476
# 50896      0.169188     0.242423
# 50897      0.004630     0.316515
# 50898      0.169188     0.592476
# 50899      0.169188     0.142614
# 50900     -0.246279     0.786745
# 50901     -0.246279     0.786745
# 50902     -0.246279     1.169884
# 50903      0.004630     0.586296
# 50904      0.004630     0.514406
# 50905      0.004630     0.316515
#
# [50906 rows x 6 columns]

# %%
# per eventualmente riportare il dataset ai valori originali
#pd.DataFrame(scaler.inverse_transform(df_Clustering[col_toScale].head().values), columns = col_toScale)

# %% [markdown]
# ## 2) Tasformazioni per la Classification

# %% [markdown]
# ## 3) Tasformazioni per la Association

# %%
df_Association.isnull().sum()
# Out:
# PurchDate                                0
# Model                                    0
# SubModel                                 0
# VehYear                                  0
# RefId                                    0
# IsBadBuy                                 0
# Auction                                  0
# VehicleAge                               0
# Make                                     0
# Engine                               17828
# Trim                                     0
# Transmission                             0
# WheelTypeID                              0
# VehOdo                                   0
# Nationality                              0
# Size                                     0
# TopThreeAmericanName                     0
# MMRAcquisitionAuctionAveragePrice        0
# BYRNO                                    0
# VNZIP1                                   0
# VNST                                     0
# VehBCost                                 0
# IsOnlineSale                             0
# WarrantyCost                             0
# Doors                                 6409
# dtype: int64

# %% [markdown]
# ** Modifiche degli attributi **

# %% [markdown]
# - 'PurchDate'

# %% [markdown]
# di questo attributo teniamo solo i valori di mese e anno (non il giorno) in maniera da ridurre il numero di categorie di valori.

# %%
df_Association["PurchDate"].nunique()
# Out:
# 516

# %%
df_Association['PurchYearMonth'] = pd.to_datetime(df_Association['PurchDate']).dt.to_period('M')
df_Association['PurchYearMonth']
# Out:
# 0       2009-01
# 1       2009-01
# 2       2009-01
# 3       2009-01
# 4       2009-01
# 5       2009-01
# 6       2009-01
# 7       2009-01
# 8       2009-01
# 9       2009-01
# 10      2009-01
# 11      2009-01
# 12      2009-01
# 13      2009-01
# 14      2009-01
# 15      2009-01
# 16      2009-01
# 17      2009-01
# 18      2009-01
# 19      2009-01
# 20      2009-01
# 21      2009-01
# 22      2009-01
# 23      2009-01
# 24      2009-01
# 25      2009-01
# 26      2009-01
# 27      2009-01
# 28      2009-01
# 29      2009-01
#           ...
# 50876   2010-12
# 50877   2010-12
# 50878   2010-12
# 50879   2010-12
# 50880   2010-12
# 50881   2010-12
# 50882   2010-12
# 50883   2010-12
# 50884   2010-12
# 50885   2010-12
# 50886   2010-12
# 50887   2010-12
# 50888   2010-12
# 50889   2010-12
# 50890   2010-12
# 50891   2010-12
# 50892   2010-12
# 50893   2010-12
# 50894   2010-12
# 50895   2010-12
# 50896   2010-12
# 50897   2010-12
# 50898   2010-12
# 50899   2010-12
# 50900   2010-12
# 50901   2010-12
# 50902   2010-12
# 50903   2010-12
# 50904   2010-12
# 50905   2010-12
# Name: PurchYearMonth, Length: 50906, dtype: object

# %%
df_Association["PurchYearMonth"].nunique()
# Out:
# 24

# %%
del df_Association['PurchDate']

# %% [markdown]
# - 'RefId'

# %%
del df_Association['RefId']

# %% [markdown]
# ** Binning delle Variabili Numeriche **

# %%
df_Association.nunique()
# Out:
# Model                                  261
# SubModel                                38
# VehYear                                 10
# IsBadBuy                                 2
# Auction                                  3
# VehicleAge                              10
# Make                                    32
# Engine                                 127
# Trim                                   129
# Transmission                             2
# WheelTypeID                              3
# VehOdo                               32709
# Nationality                              2
# Size                                    12
# TopThreeAmericanName                     4
# MMRAcquisitionAuctionAveragePrice     9703
# BYRNO                                   72
# VNZIP1                                 152
# VNST                                    37
# VehBCost                              1982
# IsOnlineSale                             2
# WarrantyCost                           276
# Doors                                    4
# PurchYearMonth                          24
# dtype: int64

# %%
df_Association.dtypes
# Out:
# Model                                 object
# SubModel                              object
# VehYear                                int64
# IsBadBuy                               int64
# Auction                               object
# VehicleAge                             int64
# Make                                  object
# Engine                                object
# Trim                                  object
# Transmission                          object
# WheelTypeID                          float64
# VehOdo                                 int64
# Nationality                           object
# Size                                  object
# TopThreeAmericanName                  object
# MMRAcquisitionAuctionAveragePrice    float64
# BYRNO                                  int64
# VNZIP1                                 int64
# VNST                                  object
# VehBCost                             float64
# IsOnlineSale                           int64
# WarrantyCost                           int64
# Doors                                 object
# PurchYearMonth                        object
# dtype: object

# %%
col_toBin = df_Association.select_dtypes(['float64', 'int64']).columns.difference(['VNZIP1', 'IsBadBuy', 'IsOnlineSale',
                                                                                   'BYRNO', 'VehicleAge', 'WheelTypeID'])
col_toBin
# Out:
# Index(['MMRAcquisitionAuctionAveragePrice', 'VehBCost', 'VehOdo', 'VehYear',
#        'WarrantyCost'],
#       dtype='object')

# %%
Bins = 80

# %%
for col in col_toBin:
    if df_Association[col].nunique() > Bins:
        df_Association[col + 'Bin'] = pd.cut(df_Association[col].astype(int), Bins, right=False)
        del df_Association[col]

df_Association.nunique()
# Out:
# Model                                   261
# SubModel                                 38
# VehYear                                  10
# IsBadBuy                                  2
# Auction                                   3
# VehicleAge                               10
# Make                                     32
# Engine                                  127
# Trim                                    129
# Transmission                              2
# WheelTypeID                               3
# Nationality                               2
# Size                                     12
# TopThreeAmericanName                      4
# BYRNO                                    72
# VNZIP1                                  152
# VNST                                     37
# IsOnlineSale                              2
# Doors                                     4
# PurchYearMonth                           24
# MMRAcquisitionAuctionAveragePriceBin     56
# VehBCostBin                              41
# VehOdoBin                                77
# WarrantyCostBin                          54
# dtype: int64

# %%
df_Association
# Out:
#               Model       SubModel  VehYear  IsBadBuy  Auction  VehicleAge  \
# 0          1500 RAM       QUAD CAB     2002         0    ADESA           7
# 1          1500 RAM       QUAD CAB     2003         0  MANHEIM           6
# 2          1500 RAM       QUAD CAB     2005         0  MANHEIM           4
# 3               300          SEDAN     2006         0    ADESA           3
# 4               300          SEDAN     2006         0  MANHEIM           3
# 5               300          SEDAN     2006         0  MANHEIM           3
# 6            ACCENT          SEDAN     2004         0    OTHER           5
# 7            ACCENT          SEDAN     2005         1    OTHER           4
# 8            ACCORD          COUPE     2005         0  MANHEIM           4
# 9             AERIO          SEDAN     2003         1    OTHER           6
# 10            AERIO          SEDAN     2004         0    OTHER           5
# 11           ALTIMA          SEDAN     2003         0  MANHEIM           6
# 12             AVEO          SEDAN     2004         1  MANHEIM           5
# 13       BONNEVILLE          SEDAN     2004         1    ADESA           5
# 14            CAMRY          SEDAN     2003         0    ADESA           6
# 15          CARAVAN        MINIVAN     2001         0    OTHER           8
# 16         CAVALIER          COUPE     2004         0    ADESA           5
# 17         CAVALIER          SEDAN     2004         0  MANHEIM           5
# 18         CAVALIER          SEDAN     2005         0    OTHER           4
# 19          CENTURY          SEDAN     2002         0  MANHEIM           7
# 20          CENTURY          SEDAN     2005         0    OTHER           4
# 21          CHARGER          SEDAN     2006         0    ADESA           3
# 22          CHARGER          SEDAN     2006         0  MANHEIM           3
# 23          CHARGER          SEDAN     2006         0  MANHEIM           3
# 24        COMMANDER          WAGON     2006         0    ADESA           3
# 25           DAKOTA       QUAD CAB     2005         0    ADESA           4
# 26          DURANGO            SUV     2001         0    ADESA           8
# 27          DURANGO            SUV     2003         0    ADESA           6
# 28          DURANGO            SUV     2006         1  MANHEIM           3
# 29          ELANTRA          SEDAN     2005         0    ADESA           4
# ...             ...            ...      ...       ...      ...         ...
# 50876   TRAILBLAZER            SUV     2005         0  MANHEIM           5
# 50877           VUE            CUV     2005         0  MANHEIM           5
# 50878           VUE            CUV     2006         0  MANHEIM           4
# 50879       CHARGER          SEDAN     2006         0  MANHEIM           4
# 50880        COBALT          SEDAN     2005         0  MANHEIM           5
# 50881       ELANTRA          SEDAN     2005         0  MANHEIM           5
# 50882         FOCUS          SEDAN     2004         0  MANHEIM           6
# 50883      GRAND AM          SEDAN     2005         0  MANHEIM           5
# 50884         MILAN          SEDAN     2008         0  MANHEIM           2
# 50885          NEON          SEDAN     2005         0  MANHEIM           5
# 50886        OPTIMA          SEDAN     2005         0  MANHEIM           5
# 50887    PATHFINDER  UTILITY SPORT     2001         1  MANHEIM           9
# 50888    PT CRUISER    CONVERTIBLE     2005         1  MANHEIM           5
# 50889        TAURUS          SEDAN     2006         0  MANHEIM           4
# 50890            XB          WAGON     2006         0    OTHER           4
# 50891        ACCORD          SEDAN     2006         0    ADESA           4
# 50892         AERIO          SEDAN     2004         0    ADESA           6
# 50893         AERIO          WAGON     2006         0    ADESA           4
# 50894       CARAVAN        MINIVAN     2003         1    ADESA           7
# 50895       CARAVAN        MINIVAN     2005         1    ADESA           5
# 50896         CIVIC          COUPE     2004         0    ADESA           6
# 50897           CTS          SEDAN     2003         0    ADESA           7
# 50898       FORENZA          SEDAN     2006         0    ADESA           4
# 50899       FORENZA          SEDAN     2007         0    ADESA           3
# 50900      FREESTAR      PASSENGER     2004         0  MANHEIM           6
# 50901  GRAND VITARA  UTILITY SPORT     2006         1    ADESA           4
# 50902        MALIBU          SEDAN     2005         1  MANHEIM           5
# 50903       SPECTRA          SEDAN     2006         0    ADESA           4
# 50904        TAURUS          SEDAN     2006         0    ADESA           4
# 50905   TRAILBLAZER            SUV     2005         0    ADESA           5
#
#             Make       Engine Trim Transmission        ...          BYRNO  \
# 0          DODGE         5.9L   ST         AUTO        ...          20234
# 1          DODGE         5.7L  LAR         AUTO        ...          19619
# 2          DODGE         5.7L  SLT         AUTO        ...          19619
# 3       CHRYSLER     2.7L MPI  BAS         AUTO        ...          20234
# 4       CHRYSLER     2.7L MPI  BAS         AUTO        ...          20833
# 5       CHRYSLER     2.7L MPI  BAS         AUTO        ...          20928
# 6        HYUNDAI     1.6L MPI   GL         AUTO        ...            835
# 7        HYUNDAI     1.6L MPI  GLS         AUTO        ...            835
# 8          HONDA      4C 2.4L   SE         AUTO        ...          20392
# 9         SUZUKI     2.0L EFI    S         AUTO        ...            835
# 10        SUZUKI     2.3L SFI    S         AUTO        ...            835
# 11        NISSAN     2.5L EFI  BAS         AUTO        ...          19619
# 12     CHEVROLET     1.6L MPI   LS         AUTO        ...          23359
# 13       PONTIAC         3.8L   SE         AUTO        ...          16044
# 14        TOYOTA  4C 2.4L EFI   LE         AUTO        ...          18111
# 15         DODGE         3.3L  SPO         AUTO        ...            835
# 16     CHEVROLET      4C 2.2L  BAS       MANUAL        ...          18880
# 17     CHEVROLET      4C 2.2L   LS         AUTO        ...          20207
# 18     CHEVROLET      4C 2.2L  BAS         AUTO        ...            835
# 19         BUICK         3.1L  CUS         AUTO        ...          19638
# 20         BUICK         3.1L  CUS         AUTO        ...            835
# 21         DODGE     2.7L MPI  BAS         AUTO        ...          20234
# 22         DODGE     2.7L MPI  BAS         AUTO        ...          19638
# 23         DODGE     2.7L MPI  BAS         AUTO        ...          19638
# 24          JEEP         3.7L  BAS         AUTO        ...          18111
# 25         DODGE         3.7L   ST         AUTO        ...          20234
# 26         DODGE      V8 4.7L  SLT         AUTO        ...          18111
# 27         DODGE      V8 4.7L  SPO         AUTO        ...            835
# 28         DODGE      V8 4.7L  SXT         AUTO        ...          20833
# 29       HYUNDAI     2.0L MPI  GLS         AUTO        ...            835
# ...          ...          ...  ...          ...        ...            ...
# 50876  CHEVROLET           6C   LS         AUTO        ...          25100
# 50877     SATURN           4C  BAS         AUTO        ...          25100
# 50878     SATURN           4C  BAS       MANUAL        ...          21047
# 50879      DODGE          NaN  BAS         AUTO        ...          21047
# 50880  CHEVROLET          NaN  BAS         AUTO        ...          10315
# 50881    HYUNDAI          NaN  GLS         AUTO        ...          25100
# 50882       FORD          NaN   SE         AUTO        ...          10315
# 50883    PONTIAC           4C   SE         AUTO        ...          21047
# 50884    MERCURY           4C  BAS         AUTO        ...          10315
# 50885      DODGE          NaN  SXT         AUTO        ...          25100
# 50886        KIA           4C   EX         AUTO        ...          21047
# 50887     NISSAN          NaN   LE         AUTO        ...          21047
# 50888   CHRYSLER          NaN  BAS         AUTO        ...          25100
# 50889       FORD          NaN   SE         AUTO        ...          25100
# 50890      SCION          NaN  BAS       MANUAL        ...          20740
# 50891      HONDA           4C   SE         AUTO        ...          20740
# 50892     SUZUKI          NaN    S       MANUAL        ...          20740
# 50893     SUZUKI          NaN   SX         AUTO        ...          52598
# 50894      DODGE         3.8L   EX         AUTO        ...          20740
# 50895      DODGE         3.3L   SE         AUTO        ...          20740
# 50896      HONDA          NaN   VP         AUTO        ...          52598
# 50897   CADILLAC          NaN  BAS         AUTO        ...          20740
# 50898     SUZUKI          NaN  BAS         AUTO        ...          52598
# 50899     SUZUKI          NaN  BAS       MANUAL        ...          52598
# 50900       FORD         3.9L  SES         AUTO        ...          21047
# 50901     SUZUKI          NaN  BAS         AUTO        ...          52598
# 50902  CHEVROLET           4C  CLA         AUTO        ...          21047
# 50903        KIA          NaN   EX         AUTO        ...          20740
# 50904       FORD          NaN   SE         AUTO        ...          52598
# 50905  CHEVROLET           6C   LS         AUTO        ...          20740
#
#       VNZIP1 VNST IsOnlineSale  Doors  PurchYearMonth  \
# 0      85226   AZ            0    NaN         2009-01
# 1      32824   FL            0    NaN         2009-01
# 2      32824   FL            0    NaN         2009-01
# 3      85226   AZ            0     4D         2009-01
# 4      75236   TX            0     4D         2009-01
# 5      32824   FL            0     4D         2009-01
# 6      85009   AZ            0     4D         2009-01
# 7      85009   AZ            0     4D         2009-01
# 8      75236   TX            0     2D         2009-01
# 9      85009   AZ            0     4D         2009-01
# 10     85009   AZ            0     4D         2009-01
# 11     32824   FL            0     4D         2009-01
# 12     92057   CA            0     4D         2009-01
# 13     30212   GA            0     4D         2009-01
# 14     30212   GA            0     4D         2009-01
# 15     85009   AZ            0    NaN         2009-01
# 16     30212   GA            0     2D         2009-01
# 17     64161   MO            0     4D         2009-01
# 18     85009   AZ            0     4D         2009-01
# 19     33809   FL            0     4D         2009-01
# 20     85009   AZ            0     4D         2009-01
# 21     85226   AZ            0     4D         2009-01
# 22     33809   FL            0     4D         2009-01
# 23     33809   FL            0     4D         2009-01
# 24     30212   GA            0     4D         2009-01
# 25     85226   AZ            0    NaN         2009-01
# 26     30212   GA            0     4D         2009-01
# 27     85226   AZ            0     4D         2009-01
# 28     75236   TX            0     4D         2009-01
# 29     85226   AZ            0     4D         2009-01
# ...      ...  ...          ...    ...             ...
# 50876  75050   TX            0     4D         2010-12
# 50877  75050   TX            0     4D         2010-12
# 50878  92504   CA            0     4D         2010-12
# 50879  92807   CA            0     4D         2010-12
# 50880  32824   FL            1     4D         2010-12
# 50881  75236   TX            0     4D         2010-12
# 50882  32824   FL            1     4D         2010-12
# 50883  92807   CA            0     4D         2010-12
# 50884  32824   FL            1     4D         2010-12
# 50885  75236   TX            0     4D         2010-12
# 50886  92807   CA            0     4D         2010-12
# 50887  92807   CA            0     4D         2010-12
# 50888  75236   TX            0     2D         2010-12
# 50889  75236   TX            0     4D         2010-12
# 50890  29461   SC            0     4D         2010-12
# 50891  32219   FL            0     4D         2010-12
# 50892  32219   FL            0     4D         2010-12
# 50893  28273   NC            0     4D         2010-12
# 50894  32219   FL            0    NaN         2010-12
# 50895  32219   FL            0    NaN         2010-12
# 50896  28273   NC            0     2D         2010-12
# 50897  32219   FL            0     4D         2010-12
# 50898  28273   NC            0     4D         2010-12
# 50899  28273   NC            0     4D         2010-12
# 50900  92337   CA            0     4D         2010-12
# 50901  28273   NC            0     4D         2010-12
# 50902  92337   CA            0     4D         2010-12
# 50903  32219   FL            0     4D         2010-12
# 50904  28273   NC            0     4D         2010-12
# 50905  32219   FL            0     4D         2010-12
#
#       MMRAcquisitionAuctionAveragePriceBin          VehBCostBin  \
# 0                       [5674.225, 6109.7)    [7753.85, 8209.9)
# 1                       [7416.125, 7851.6)    [9122.0, 9578.05)
# 2                    [10028.975, 10464.45)   [9578.05, 10034.1)
# 3                       [9158.025, 9593.5)    [9122.0, 9578.05)
# 4                       [9158.025, 9593.5)  [10034.1, 10490.15)
# 5                       [9158.025, 9593.5)   [9578.05, 10034.1)
# 6                       [2625.9, 3061.375)    [4105.45, 4561.5)
# 7                      [3061.375, 3496.85)    [5017.55, 5473.6)
# 8                      [8287.075, 8722.55)    [8209.9, 8665.95)
# 9                      [1754.95, 2190.425)    [4105.45, 4561.5)
# 10                     [3061.375, 3496.85)    [5017.55, 5473.6)
# 11                      [4367.8, 4803.275)    [6385.7, 6841.75)
# 12                      [2625.9, 3061.375)    [4105.45, 4561.5)
# 13                      [4367.8, 4803.275)    [5473.6, 5929.65)
# 14                      [5674.225, 6109.7)    [7753.85, 8209.9)
# 15                      [2190.425, 2625.9)    [3649.4, 4105.45)
# 16                      [2625.9, 3061.375)    [3193.35, 3649.4)
# 17                     [3061.375, 3496.85)    [3649.4, 4105.45)
# 18                     [3061.375, 3496.85)    [4561.5, 5017.55)
# 19                      [2625.9, 3061.375)    [4105.45, 4561.5)
# 20                      [3932.325, 4367.8)    [4561.5, 5017.55)
# 21                      [9158.025, 9593.5)    [9122.0, 9578.05)
# 22                      [9158.025, 9593.5)  [10034.1, 10490.15)
# 23                      [9158.025, 9593.5)  [10034.1, 10490.15)
# 24                   [12206.35, 12641.825)  [10034.1, 10490.15)
# 25                      [7851.6, 8287.075)    [8209.9, 8665.95)
# 26                     [3061.375, 3496.85)    [4561.5, 5017.55)
# 27                      [4367.8, 4803.275)    [5017.55, 5473.6)
# 28                      [7851.6, 8287.075)    [7297.8, 7753.85)
# 29                     [3496.85, 3932.325)    [5473.6, 5929.65)
# ...                                    ...                  ...
# 20       [85371.025, 86750.388)  [2133.05, 2221.0)
# 21       [72956.762, 74336.125)  [1341.5, 1429.45)
# 22       [67439.312, 68818.675)  [1165.6, 1253.55)
# 23         [59163.138, 60542.5)  [1077.65, 1165.6)
# 24       [79853.575, 81232.938)  [1869.2, 1957.15)
# 25         [71577.4, 72956.762)  [1605.35, 1693.3)
# 26        [64680.588, 66059.95)  [1693.3, 1781.25)
# 27        [75715.488, 77094.85)  [1605.35, 1693.3)
# 28         [82612.3, 83991.662)  [1429.45, 1517.4)
# 29        [42610.788, 43990.15)    [462.0, 549.95)
# ...                         ...                ...
# 50876     [97785.287, 99164.65)  [1253.55, 1341.5)
# 50877    [90888.475, 92267.838)  [1869.2, 1957.15)
# 50878    [67439.312, 68818.675)  [1341.5, 1429.45)
# 50879      [82612.3, 83991.662)  [1429.45, 1517.4)
# 50880    [67439.312, 68818.675)    [725.85, 813.8)
# 50881      [82612.3, 83991.662)    [549.95, 637.9)
# 50882     [55025.05, 56404.412)    [901.75, 989.7)
# 50883    [90888.475, 92267.838)  [1693.3, 1781.25)
# 50884     [75715.488, 77094.85)    [725.85, 813.8)
# 50885    [96405.925, 97785.287)    [725.85, 813.8)
# 50886     [55025.05, 56404.412)    [637.9, 725.85)
# 50887      [92267.838, 93647.2)  [1165.6, 1253.55)
# 50888    [67439.312, 68818.675)  [1165.6, 1253.55)
# 50889    [103302.738, 104682.1)  [1077.65, 1165.6)
# 50890    [85371.025, 86750.388)    [549.95, 637.9)
# 50891     [77094.85, 78474.212)    [549.95, 637.9)
# 50892    [74336.125, 75715.488)    [901.75, 989.7)
# 50893      [82612.3, 83991.662)    [901.75, 989.7)
# 50894  [101923.375, 103302.738)  [2308.95, 2396.9)
# 50895    [78474.212, 79853.575)  [1605.35, 1693.3)
# 50896    [96405.925, 97785.287)    [725.85, 813.8)
# 50897    [85371.025, 86750.388)  [2045.1, 2133.05)
# 50898    [72956.762, 74336.125)    [549.95, 637.9)
# 50899    [52266.325, 53645.688)    [462.0, 549.95)
# 50900  [106061.462, 107440.825)  [1869.2, 1957.15)
# 50901     [55025.05, 56404.412)    [901.75, 989.7)
# 50902    [79853.575, 81232.938)  [1165.6, 1253.55)
# 50903     [42610.788, 43990.15)    [462.0, 549.95)
# 50904    [68818.675, 70198.038)    [813.8, 901.75)
# 50905      [70198.038, 71577.4)  [1077.65, 1165.6)
#
# [50906 rows x 24 columns]

# %% [markdown]
# ** Append dell'Intestazione delle Colonne **

# %%
for col in df_Association.columns:
    df_Association[col] = df_Association[col].astype(str) + '_' + str(col)

# %%
df_Association
# Out:
#                     Model                SubModel       VehYear    IsBadBuy  \
# 0          1500 RAM_Model       QUAD CAB_SubModel  2002_VehYear  0_IsBadBuy
# 1          1500 RAM_Model       QUAD CAB_SubModel  2003_VehYear  0_IsBadBuy
# 2          1500 RAM_Model       QUAD CAB_SubModel  2005_VehYear  0_IsBadBuy
# 3               300_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 4               300_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 5               300_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 6            ACCENT_Model          SEDAN_SubModel  2004_VehYear  0_IsBadBuy
# 7            ACCENT_Model          SEDAN_SubModel  2005_VehYear  1_IsBadBuy
# 8            ACCORD_Model          COUPE_SubModel  2005_VehYear  0_IsBadBuy
# 9             AERIO_Model          SEDAN_SubModel  2003_VehYear  1_IsBadBuy
# 10            AERIO_Model          SEDAN_SubModel  2004_VehYear  0_IsBadBuy
# 11           ALTIMA_Model          SEDAN_SubModel  2003_VehYear  0_IsBadBuy
# 12             AVEO_Model          SEDAN_SubModel  2004_VehYear  1_IsBadBuy
# 13       BONNEVILLE_Model          SEDAN_SubModel  2004_VehYear  1_IsBadBuy
# 14            CAMRY_Model          SEDAN_SubModel  2003_VehYear  0_IsBadBuy
# 15          CARAVAN_Model        MINIVAN_SubModel  2001_VehYear  0_IsBadBuy
# 16         CAVALIER_Model          COUPE_SubModel  2004_VehYear  0_IsBadBuy
# 17         CAVALIER_Model          SEDAN_SubModel  2004_VehYear  0_IsBadBuy
# 18         CAVALIER_Model          SEDAN_SubModel  2005_VehYear  0_IsBadBuy
# 19          CENTURY_Model          SEDAN_SubModel  2002_VehYear  0_IsBadBuy
# 20          CENTURY_Model          SEDAN_SubModel  2005_VehYear  0_IsBadBuy
# 21          CHARGER_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 22          CHARGER_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 23          CHARGER_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 24        COMMANDER_Model          WAGON_SubModel  2006_VehYear  0_IsBadBuy
# 25           DAKOTA_Model       QUAD CAB_SubModel  2005_VehYear  0_IsBadBuy
# 26          DURANGO_Model            SUV_SubModel  2001_VehYear  0_IsBadBuy
# 27          DURANGO_Model            SUV_SubModel  2003_VehYear  0_IsBadBuy
# 28          DURANGO_Model            SUV_SubModel  2006_VehYear  1_IsBadBuy
# 29          ELANTRA_Model          SEDAN_SubModel  2005_VehYear  0_IsBadBuy
# ...                   ...                     ...           ...         ...
# 50876   TRAILBLAZER_Model            SUV_SubModel  2005_VehYear  0_IsBadBuy
# 50877           VUE_Model            CUV_SubModel  2005_VehYear  0_IsBadBuy
# 50878           VUE_Model            CUV_SubModel  2006_VehYear  0_IsBadBuy
# 50879       CHARGER_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 50880        COBALT_Model          SEDAN_SubModel  2005_VehYear  0_IsBadBuy
# 50881       ELANTRA_Model          SEDAN_SubModel  2005_VehYear  0_IsBadBuy
# 50882         FOCUS_Model          SEDAN_SubModel  2004_VehYear  0_IsBadBuy
# 50883      GRAND AM_Model          SEDAN_SubModel  2005_VehYear  0_IsBadBuy
# 50884         MILAN_Model          SEDAN_SubModel  2008_VehYear  0_IsBadBuy
# 50885          NEON_Model          SEDAN_SubModel  2005_VehYear  0_IsBadBuy
# 50886        OPTIMA_Model          SEDAN_SubModel  2005_VehYear  0_IsBadBuy
# 50887    PATHFINDER_Model  UTILITY SPORT_SubModel  2001_VehYear  1_IsBadBuy
# 50888    PT CRUISER_Model    CONVERTIBLE_SubModel  2005_VehYear  1_IsBadBuy
# 50889        TAURUS_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 50890            XB_Model          WAGON_SubModel  2006_VehYear  0_IsBadBuy
# 50891        ACCORD_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 50892         AERIO_Model          SEDAN_SubModel  2004_VehYear  0_IsBadBuy
# 50893         AERIO_Model          WAGON_SubModel  2006_VehYear  0_IsBadBuy
# 50894       CARAVAN_Model        MINIVAN_SubModel  2003_VehYear  1_IsBadBuy
# 50895       CARAVAN_Model        MINIVAN_SubModel  2005_VehYear  1_IsBadBuy
# 50896         CIVIC_Model          COUPE_SubModel  2004_VehYear  0_IsBadBuy
# 50897           CTS_Model          SEDAN_SubModel  2003_VehYear  0_IsBadBuy
# 50898       FORENZA_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 50899       FORENZA_Model          SEDAN_SubModel  2007_VehYear  0_IsBadBuy
# 50900      FREESTAR_Model      PASSENGER_SubModel  2004_VehYear  0_IsBadBuy
# 50901  GRAND VITARA_Model  UTILITY SPORT_SubModel  2006_VehYear  1_IsBadBuy
# 50902        MALIBU_Model          SEDAN_SubModel  2005_VehYear  1_IsBadBuy
# 50903       SPECTRA_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 50904        TAURUS_Model          SEDAN_SubModel  2006_VehYear  0_IsBadBuy
# 50905   TRAILBLAZER_Model            SUV_SubModel  2005_VehYear  0_IsBadBuy
#
#                Auction    VehicleAge            Make              Engine  \
# 0        ADESA_Auction  7_VehicleAge      DODGE_Make         5.9L_Engine
# 1      MANHEIM_Auction  6_VehicleAge      DODGE_Make         5.7L_Engine
# 2      MANHEIM_Auction  4_VehicleAge      DODGE_Make         5.7L_Engine
# 3        ADESA_Auction  3_VehicleAge   CHRYSLER_Make     2.7L MPI_Engine
# 4      MANHEIM_Auction  3_VehicleAge   CHRYSLER_Make     2.7L MPI_Engine
# 5      MANHEIM_Auction  3_VehicleAge   CHRYSLER_Make     2.7L MPI_Engine
# 6        OTHER_Auction  5_VehicleAge    HYUNDAI_Make     1.6L MPI_Engine
# 7        OTHER_Auction  4_VehicleAge    HYUNDAI_Make     1.6L MPI_Engine
# 8      MANHEIM_Auction  4_VehicleAge      HONDA_Make      4C 2.4L_Engine
# 9        OTHER_Auction  6_VehicleAge     SUZUKI_Make     2.0L EFI_Engine
# 10       OTHER_Auction  5_VehicleAge     SUZUKI_Make     2.3L SFI_Engine
# 11     MANHEIM_Auction  6_VehicleAge     NISSAN_Make     2.5L EFI_Engine
# 12     MANHEIM_Auction  5_VehicleAge  CHEVROLET_Make     1.6L MPI_Engine
# 13       ADESA_Auction  5_VehicleAge    PONTIAC_Make         3.8L_Engine
# 14       ADESA_Auction  6_VehicleAge     TOYOTA_Make  4C 2.4L EFI_Engine
# 15       OTHER_Auction  8_VehicleAge      DODGE_Make         3.3L_Engine
# 16       ADESA_Auction  5_VehicleAge  CHEVROLET_Make      4C 2.2L_Engine
# 17     MANHEIM_Auction  5_VehicleAge  CHEVROLET_Make      4C 2.2L_Engine
# 18       OTHER_Auction  4_VehicleAge  CHEVROLET_Make      4C 2.2L_Engine
# 19     MANHEIM_Auction  7_VehicleAge      BUICK_Make         3.1L_Engine
# 20       OTHER_Auction  4_VehicleAge      BUICK_Make         3.1L_Engine
# 21       ADESA_Auction  3_VehicleAge      DODGE_Make     2.7L MPI_Engine
# 22     MANHEIM_Auction  3_VehicleAge      DODGE_Make     2.7L MPI_Engine
# 23     MANHEIM_Auction  3_VehicleAge      DODGE_Make     2.7L MPI_Engine
# 24       ADESA_Auction  3_VehicleAge       JEEP_Make         3.7L_Engine
# 25       ADESA_Auction  4_VehicleAge      DODGE_Make         3.7L_Engine
# 26       ADESA_Auction  8_VehicleAge      DODGE_Make      V8 4.7L_Engine
# 27       ADESA_Auction  6_VehicleAge      DODGE_Make      V8 4.7L_Engine
# 28     MANHEIM_Auction  3_VehicleAge      DODGE_Make      V8 4.7L_Engine
# 29       ADESA_Auction  4_VehicleAge    HYUNDAI_Make     2.0L MPI_Engine
# ...                ...           ...             ...                 ...
# 50876  MANHEIM_Auction  5_VehicleAge  CHEVROLET_Make           6C_Engine
# 50877  MANHEIM_Auction  5_VehicleAge     SATURN_Make           4C_Engine
# 50878  MANHEIM_Auction  4_VehicleAge     SATURN_Make           4C_Engine
# 50879  MANHEIM_Auction  4_VehicleAge      DODGE_Make          nan_Engine
# 50880  MANHEIM_Auction  5_VehicleAge  CHEVROLET_Make          nan_Engine
# 50881  MANHEIM_Auction  5_VehicleAge    HYUNDAI_Make          nan_Engine
# 50882  MANHEIM_Auction  6_VehicleAge       FORD_Make          nan_Engine
# 50883  MANHEIM_Auction  5_VehicleAge    PONTIAC_Make           4C_Engine
# 50884  MANHEIM_Auction  2_VehicleAge    MERCURY_Make           4C_Engine
# 50885  MANHEIM_Auction  5_VehicleAge      DODGE_Make          nan_Engine
# 50886  MANHEIM_Auction  5_VehicleAge        KIA_Make           4C_Engine
# 50887  MANHEIM_Auction  9_VehicleAge     NISSAN_Make          nan_Engine
# 50888  MANHEIM_Auction  5_VehicleAge   CHRYSLER_Make          nan_Engine
# 50889  MANHEIM_Auction  4_VehicleAge       FORD_Make          nan_Engine
# 50890    OTHER_Auction  4_VehicleAge      SCION_Make          nan_Engine
# 50891    ADESA_Auction  4_VehicleAge      HONDA_Make           4C_Engine
# 50892    ADESA_Auction  6_VehicleAge     SUZUKI_Make          nan_Engine
# 50893    ADESA_Auction  4_VehicleAge     SUZUKI_Make          nan_Engine
# 50894    ADESA_Auction  7_VehicleAge      DODGE_Make         3.8L_Engine
# 50895    ADESA_Auction  5_VehicleAge      DODGE_Make         3.3L_Engine
# 50896    ADESA_Auction  6_VehicleAge      HONDA_Make          nan_Engine
# 50897    ADESA_Auction  7_VehicleAge   CADILLAC_Make          nan_Engine
# 50898    ADESA_Auction  4_VehicleAge     SUZUKI_Make          nan_Engine
# 50899    ADESA_Auction  3_VehicleAge     SUZUKI_Make          nan_Engine
# 50900  MANHEIM_Auction  6_VehicleAge       FORD_Make         3.9L_Engine
# 50901    ADESA_Auction  4_VehicleAge     SUZUKI_Make          nan_Engine
# 50902  MANHEIM_Auction  5_VehicleAge  CHEVROLET_Make           4C_Engine
# 50903    ADESA_Auction  4_VehicleAge        KIA_Make          nan_Engine
# 50904    ADESA_Auction  4_VehicleAge       FORD_Make          nan_Engine
# 50905    ADESA_Auction  5_VehicleAge  CHEVROLET_Make           6C_Engine
#
#            Trim         Transmission                ...                  \
# 0       ST_Trim    AUTO_Transmission                ...
# 1      LAR_Trim    AUTO_Transmission                ...
# 2      SLT_Trim    AUTO_Transmission                ...
# 3      BAS_Trim    AUTO_Transmission                ...
# 4      BAS_Trim    AUTO_Transmission                ...
# 5      BAS_Trim    AUTO_Transmission                ...
# 6       GL_Trim    AUTO_Transmission                ...
# 7      GLS_Trim    AUTO_Transmission                ...
# 8       SE_Trim    AUTO_Transmission                ...
# 9        S_Trim    AUTO_Transmission                ...
# 10       S_Trim    AUTO_Transmission                ...
# 11     BAS_Trim    AUTO_Transmission                ...
# 12      LS_Trim    AUTO_Transmission                ...
# 13      SE_Trim    AUTO_Transmission                ...
# 14      LE_Trim    AUTO_Transmission                ...
# 15     SPO_Trim    AUTO_Transmission                ...
# 16     BAS_Trim  MANUAL_Transmission                ...
# 17      LS_Trim    AUTO_Transmission                ...
# 18     BAS_Trim    AUTO_Transmission                ...
# 19     CUS_Trim    AUTO_Transmission                ...
# 20     CUS_Trim    AUTO_Transmission                ...
# 21     BAS_Trim    AUTO_Transmission                ...
# 22     BAS_Trim    AUTO_Transmission                ...
# 23     BAS_Trim    AUTO_Transmission                ...
# 24     BAS_Trim    AUTO_Transmission                ...
# 25      ST_Trim    AUTO_Transmission                ...
# 26     SLT_Trim    AUTO_Transmission                ...
# 27     SPO_Trim    AUTO_Transmission                ...
# 28     SXT_Trim    AUTO_Transmission                ...
# 29     GLS_Trim    AUTO_Transmission                ...
# ...         ...                  ...                ...
# 50876   LS_Trim    AUTO_Transmission                ...
# 50877  BAS_Trim    AUTO_Transmission                ...
# 50878  BAS_Trim  MANUAL_Transmission                ...
# 50879  BAS_Trim    AUTO_Transmission                ...
# 50880  BAS_Trim    AUTO_Transmission                ...
# 50881  GLS_Trim    AUTO_Transmission                ...
# 50882   SE_Trim    AUTO_Transmission                ...
# 50883   SE_Trim    AUTO_Transmission                ...
# 50884  BAS_Trim    AUTO_Transmission                ...
# 50885  SXT_Trim    AUTO_Transmission                ...
# 50886   EX_Trim    AUTO_Transmission                ...
# 50887   LE_Trim    AUTO_Transmission                ...
# 50888  BAS_Trim    AUTO_Transmission                ...
# 50889   SE_Trim    AUTO_Transmission                ...
# 50890  BAS_Trim  MANUAL_Transmission                ...
# 50891   SE_Trim    AUTO_Transmission                ...
# 50892    S_Trim  MANUAL_Transmission                ...
# 50893   SX_Trim    AUTO_Transmission                ...
# 50894   EX_Trim    AUTO_Transmission                ...
# 50895   SE_Trim    AUTO_Transmission                ...
# 50896   VP_Trim    AUTO_Transmission                ...
# 50897  BAS_Trim    AUTO_Transmission                ...
# 50898  BAS_Trim    AUTO_Transmission                ...
# 50899  BAS_Trim  MANUAL_Transmission                ...
# 50900  SES_Trim    AUTO_Transmission                ...
# 50901  BAS_Trim    AUTO_Transmission                ...
# 50902  CLA_Trim    AUTO_Transmission                ...
# 50903   EX_Trim    AUTO_Transmission                ...
# 50904   SE_Trim    AUTO_Transmission                ...
# 50905   LS_Trim    AUTO_Transmission                ...
#
#              BYRNO        VNZIP1     VNST    IsOnlineSale      Doors  \
# 0      20234_BYRNO  85226_VNZIP1  AZ_VNST  0_IsOnlineSale  nan_Doors
# 1      19619_BYRNO  32824_VNZIP1  FL_VNST  0_IsOnlineSale  nan_Doors
# 2      19619_BYRNO  32824_VNZIP1  FL_VNST  0_IsOnlineSale  nan_Doors
# 3      20234_BYRNO  85226_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# 4      20833_BYRNO  75236_VNZIP1  TX_VNST  0_IsOnlineSale   4D_Doors
# 5      20928_BYRNO  32824_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
# 6        835_BYRNO  85009_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# 7        835_BYRNO  85009_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# 8      20392_BYRNO  75236_VNZIP1  TX_VNST  0_IsOnlineSale   2D_Doors
# 9        835_BYRNO  85009_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# 10       835_BYRNO  85009_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# 11     19619_BYRNO  32824_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
# 12     23359_BYRNO  92057_VNZIP1  CA_VNST  0_IsOnlineSale   4D_Doors
# 13     16044_BYRNO  30212_VNZIP1  GA_VNST  0_IsOnlineSale   4D_Doors
# 14     18111_BYRNO  30212_VNZIP1  GA_VNST  0_IsOnlineSale   4D_Doors
# 15       835_BYRNO  85009_VNZIP1  AZ_VNST  0_IsOnlineSale  nan_Doors
# 16     18880_BYRNO  30212_VNZIP1  GA_VNST  0_IsOnlineSale   2D_Doors
# 17     20207_BYRNO  64161_VNZIP1  MO_VNST  0_IsOnlineSale   4D_Doors
# 18       835_BYRNO  85009_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# 19     19638_BYRNO  33809_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
# 20       835_BYRNO  85009_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# 21     20234_BYRNO  85226_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# 22     19638_BYRNO  33809_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
# 23     19638_BYRNO  33809_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
# 24     18111_BYRNO  30212_VNZIP1  GA_VNST  0_IsOnlineSale   4D_Doors
# 25     20234_BYRNO  85226_VNZIP1  AZ_VNST  0_IsOnlineSale  nan_Doors
# 26     18111_BYRNO  30212_VNZIP1  GA_VNST  0_IsOnlineSale   4D_Doors
# 27       835_BYRNO  85226_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# 28     20833_BYRNO  75236_VNZIP1  TX_VNST  0_IsOnlineSale   4D_Doors
# 29       835_BYRNO  85226_VNZIP1  AZ_VNST  0_IsOnlineSale   4D_Doors
# ...            ...           ...      ...             ...        ...
# 50876  25100_BYRNO  75050_VNZIP1  TX_VNST  0_IsOnlineSale   4D_Doors
# 50877  25100_BYRNO  75050_VNZIP1  TX_VNST  0_IsOnlineSale   4D_Doors
# 50878  21047_BYRNO  92504_VNZIP1  CA_VNST  0_IsOnlineSale   4D_Doors
# 50879  21047_BYRNO  92807_VNZIP1  CA_VNST  0_IsOnlineSale   4D_Doors
# 50880  10315_BYRNO  32824_VNZIP1  FL_VNST  1_IsOnlineSale   4D_Doors
# 50881  25100_BYRNO  75236_VNZIP1  TX_VNST  0_IsOnlineSale   4D_Doors
# 50882  10315_BYRNO  32824_VNZIP1  FL_VNST  1_IsOnlineSale   4D_Doors
# 50883  21047_BYRNO  92807_VNZIP1  CA_VNST  0_IsOnlineSale   4D_Doors
# 50884  10315_BYRNO  32824_VNZIP1  FL_VNST  1_IsOnlineSale   4D_Doors
# 50885  25100_BYRNO  75236_VNZIP1  TX_VNST  0_IsOnlineSale   4D_Doors
# 50886  21047_BYRNO  92807_VNZIP1  CA_VNST  0_IsOnlineSale   4D_Doors
# 50887  21047_BYRNO  92807_VNZIP1  CA_VNST  0_IsOnlineSale   4D_Doors
# 50888  25100_BYRNO  75236_VNZIP1  TX_VNST  0_IsOnlineSale   2D_Doors
# 50889  25100_BYRNO  75236_VNZIP1  TX_VNST  0_IsOnlineSale   4D_Doors
# 50890  20740_BYRNO  29461_VNZIP1  SC_VNST  0_IsOnlineSale   4D_Doors
# 50891  20740_BYRNO  32219_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
# 50892  20740_BYRNO  32219_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
# 50893  52598_BYRNO  28273_VNZIP1  NC_VNST  0_IsOnlineSale   4D_Doors
# 50894  20740_BYRNO  32219_VNZIP1  FL_VNST  0_IsOnlineSale  nan_Doors
# 50895  20740_BYRNO  32219_VNZIP1  FL_VNST  0_IsOnlineSale  nan_Doors
# 50896  52598_BYRNO  28273_VNZIP1  NC_VNST  0_IsOnlineSale   2D_Doors
# 50897  20740_BYRNO  32219_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
# 50898  52598_BYRNO  28273_VNZIP1  NC_VNST  0_IsOnlineSale   4D_Doors
# 50899  52598_BYRNO  28273_VNZIP1  NC_VNST  0_IsOnlineSale   4D_Doors
# 50900  21047_BYRNO  92337_VNZIP1  CA_VNST  0_IsOnlineSale   4D_Doors
# 50901  52598_BYRNO  28273_VNZIP1  NC_VNST  0_IsOnlineSale   4D_Doors
# 50902  21047_BYRNO  92337_VNZIP1  CA_VNST  0_IsOnlineSale   4D_Doors
# 50903  20740_BYRNO  32219_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
# 50904  52598_BYRNO  28273_VNZIP1  NC_VNST  0_IsOnlineSale   4D_Doors
# 50905  20740_BYRNO  32219_VNZIP1  FL_VNST  0_IsOnlineSale   4D_Doors
#
#                PurchYearMonth  \
# 0      2009-01_PurchYearMonth
# 1      2009-01_PurchYearMonth
# 2      2009-01_PurchYearMonth
# 3      2009-01_PurchYearMonth
# 4      2009-01_PurchYearMonth
# 5      2009-01_PurchYearMonth
# 6      2009-01_PurchYearMonth
# 7      2009-01_PurchYearMonth
# 8      2009-01_PurchYearMonth
# 9      2009-01_PurchYearMonth
# 10     2009-01_PurchYearMonth
# 11     2009-01_PurchYearMonth
# 12     2009-01_PurchYearMonth
# 13     2009-01_PurchYearMonth
# 14     2009-01_PurchYearMonth
# 15     2009-01_PurchYearMonth
# 16     2009-01_PurchYearMonth
# 17     2009-01_PurchYearMonth
# 18     2009-01_PurchYearMonth
# 19     2009-01_PurchYearMonth
# 20     2009-01_PurchYearMonth
# 21     2009-01_PurchYearMonth
# 22     2009-01_PurchYearMonth
# 23     2009-01_PurchYearMonth
# 24     2009-01_PurchYearMonth
# 25     2009-01_PurchYearMonth
# 26     2009-01_PurchYearMonth
# 27     2009-01_PurchYearMonth
# 28     2009-01_PurchYearMonth
# 29     2009-01_PurchYearMonth
# ...                       ...
# 50876  2010-12_PurchYearMonth
# 50877  2010-12_PurchYearMonth
# 50878  2010-12_PurchYearMonth
# 50879  2010-12_PurchYearMonth
# 50880  2010-12_PurchYearMonth
# 50881  2010-12_PurchYearMonth
# 50882  2010-12_PurchYearMonth
# 50883  2010-12_PurchYearMonth
# 50884  2010-12_PurchYearMonth
# 50885  2010-12_PurchYearMonth
# 50886  2010-12_PurchYearMonth
# 50887  2010-12_PurchYearMonth
# 50888  2010-12_PurchYearMonth
# 50889  2010-12_PurchYearMonth
# 50890  2010-12_PurchYearMonth
# 50891  2010-12_PurchYearMonth
# 50892  2010-12_PurchYearMonth
# 50893  2010-12_PurchYearMonth
# 50894  2010-12_PurchYearMonth
# 50895  2010-12_PurchYearMonth
# 50896  2010-12_PurchYearMonth
# 50897  2010-12_PurchYearMonth
# 50898  2010-12_PurchYearMonth
# 50899  2010-12_PurchYearMonth
# 50900  2010-12_PurchYearMonth
# 50901  2010-12_PurchYearMonth
# 50902  2010-12_PurchYearMonth
# 50903  2010-12_PurchYearMonth
# 50904  2010-12_PurchYearMonth
# 50905  2010-12_PurchYearMonth
#
#                     MMRAcquisitionAuctionAveragePriceBin  \
# 0      [5674.225, 6109.7)_MMRAcquisitionAuctionAverag...
# 1      [7416.125, 7851.6)_MMRAcquisitionAuctionAverag...
# 2      [10028.975, 10464.45)_MMRAcquisitionAuctionAve...
# 3      [9158.025, 9593.5)_MMRAcquisitionAuctionAverag...
# 4      [9158.025, 9593.5)_MMRAcquisitionAuctionAverag...
# 5      [9158.025, 9593.5)_MMRAcquisitionAuctionAverag...
# 6      [2625.9, 3061.375)_MMRAcquisitionAuctionAverag...
# 7      [3061.375, 3496.85)_MMRAcquisitionAuctionAvera...
# 8      [8287.075, 8722.55)_MMRAcquisitionAuctionAvera...
# 9      [1754.95, 2190.425)_MMRAcquisitionAuctionAvera...
# 10     [3061.375, 3496.85)_MMRAcquisitionAuctionAvera...
# 11     [4367.8, 4803.275)_MMRAcquisitionAuctionAverag...
# 12     [2625.9, 3061.375)_MMRAcquisitionAuctionAverag...
# 13     [4367.8, 4803.275)_MMRAcquisitionAuctionAverag...
# 14     [5674.225, 6109.7)_MMRAcquisitionAuctionAverag...
# 15     [2190.425, 2625.9)_MMRAcquisitionAuctionAverag...
# 16     [2625.9, 3061.375)_MMRAcquisitionAuctionAverag...
# 17     [3061.375, 3496.85)_MMRAcquisitionAuctionAvera...
# 18     [3061.375, 3496.85)_MMRAcquisitionAuctionAvera...
# 19     [2625.9, 3061.375)_MMRAcquisitionAuctionAverag...
# 20     [3932.325, 4367.8)_MMRAcquisitionAuctionAverag...
# 21     [9158.025, 9593.5)_MMRAcquisitionAuctionAverag...
# 22     [9158.025, 9593.5)_MMRAcquisitionAuctionAverag...
# 23     [9158.025, 9593.5)_MMRAcquisitionAuctionAverag...
# 24     [12206.35, 12641.825)_MMRAcquisitionAuctionAve...
# 25     [7851.6, 8287.075)_MMRAcquisitionAuctionAverag...
# 26     [3061.375, 3496.85)_MMRAcquisitionAuctionAvera...
# 27     [4367.8, 4803.275)_MMRAcquisitionAuctionAverag...
# 28     [7851.6, 8287.075)_MMRAcquisitionAuctionAverag...
# 29     [3496.85, 3932.325)_MMRAcquisitionAuctionAvera...
# ...                                                  ...
# 50876  [6109.7, 6545.175)_MMRAcquisitionAuctionAverag...
# 50877  [3932.325, 4367.8)_MMRAcquisitionAuctionAverag...
# 50878  [5674.225, 6109.7)_MMRAcquisitionAuctionAverag...
# 50879  [7851.6, 8287.075)_MMRAcquisitionAuctionAverag...
# 50880  [3496.85, 3932.325)_MMRAcquisitionAuctionAvera...
# 50893    [4105.45, 4561.5)_VehBCostBin      [82612.3, 83991.662)_VehOdoBin
# 50894    [3649.4, 4105.45)_VehBCostBin  [101923.375, 103302.738)_VehOdoBin
# 50895    [7297.8, 7753.85)_VehBCostBin    [78474.212, 79853.575)_VehOdoBin
# 50896    [5473.6, 5929.65)_VehBCostBin    [96405.925, 97785.287)_VehOdoBin
# 50897   [9578.05, 10034.1)_VehBCostBin    [85371.025, 86750.388)_VehOdoBin
# 50898    [4105.45, 4561.5)_VehBCostBin    [72956.762, 74336.125)_VehOdoBin
# 50899    [4105.45, 4561.5)_VehBCostBin    [52266.325, 53645.688)_VehOdoBin
# 50900    [3193.35, 3649.4)_VehBCostBin  [106061.462, 107440.825)_VehOdoBin
# 50901    [7297.8, 7753.85)_VehBCostBin     [55025.05, 56404.412)_VehOdoBin
# 50902    [4105.45, 4561.5)_VehBCostBin    [79853.575, 81232.938)_VehOdoBin
# 50903    [5017.55, 5473.6)_VehBCostBin     [42610.788, 43990.15)_VehOdoBin
# 50904    [5017.55, 5473.6)_VehBCostBin    [68818.675, 70198.038)_VehOdoBin
# 50905    [7753.85, 8209.9)_VehBCostBin      [70198.038, 71577.4)_VehOdoBin
#
#                          WarrantyCostBin
# 0      [1077.65, 1165.6)_WarrantyCostBin
# 1      [1165.6, 1253.55)_WarrantyCostBin
# 2        [901.75, 989.7)_WarrantyCostBin
# 3      [1341.5, 1429.45)_WarrantyCostBin
# 4      [1165.6, 1253.55)_WarrantyCostBin
# 5      [1077.65, 1165.6)_WarrantyCostBin
# 6        [901.75, 989.7)_WarrantyCostBin
# 7        [725.85, 813.8)_WarrantyCostBin
# 8        [549.95, 637.9)_WarrantyCostBin
# 9      [1165.6, 1253.55)_WarrantyCostBin
# 10       [725.85, 813.8)_WarrantyCostBin
# 11       [901.75, 989.7)_WarrantyCostBin
# 12       [725.85, 813.8)_WarrantyCostBin
# 13     [2396.9, 2484.85)_WarrantyCostBin
# 14       [813.8, 901.75)_WarrantyCostBin
# 15     [2133.05, 2221.0)_WarrantyCostBin
# 16       [901.75, 989.7)_WarrantyCostBin
# 17     [1077.65, 1165.6)_WarrantyCostBin
# 18     [1077.65, 1165.6)_WarrantyCostBin
# 19     [2221.0, 2308.95)_WarrantyCostBin
# 20     [2133.05, 2221.0)_WarrantyCostBin
# 21     [1341.5, 1429.45)_WarrantyCostBin
# 22     [1165.6, 1253.55)_WarrantyCostBin
# 23     [1077.65, 1165.6)_WarrantyCostBin
# 24     [1869.2, 1957.15)_WarrantyCostBin
# 25     [1605.35, 1693.3)_WarrantyCostBin
# 26     [1693.3, 1781.25)_WarrantyCostBin
# 27     [1605.35, 1693.3)_WarrantyCostBin
# 28     [1429.45, 1517.4)_WarrantyCostBin
# 29       [462.0, 549.95)_WarrantyCostBin
# ...                                  ...
# 50876  [1253.55, 1341.5)_WarrantyCostBin
# 50877  [1869.2, 1957.15)_WarrantyCostBin
# 50878  [1341.5, 1429.45)_WarrantyCostBin
# 50879  [1429.45, 1517.4)_WarrantyCostBin
# 50880    [725.85, 813.8)_WarrantyCostBin
# 50881    [549.95, 637.9)_WarrantyCostBin
# 50882    [901.75, 989.7)_WarrantyCostBin
# 50883  [1693.3, 1781.25)_WarrantyCostBin
# 50884    [725.85, 813.8)_WarrantyCostBin
# 50885    [725.85, 813.8)_WarrantyCostBin
# 50886    [637.9, 725.85)_WarrantyCostBin
# 50887  [1165.6, 1253.55)_WarrantyCostBin
# 50888  [1165.6, 1253.55)_WarrantyCostBin
# 50889  [1077.65, 1165.6)_WarrantyCostBin
# 50890    [549.95, 637.9)_WarrantyCostBin
# 50891    [549.95, 637.9)_WarrantyCostBin
# 50892    [901.75, 989.7)_WarrantyCostBin
# 50893    [901.75, 989.7)_WarrantyCostBin
# 50894  [2308.95, 2396.9)_WarrantyCostBin
# 50895  [1605.35, 1693.3)_WarrantyCostBin
# 50896    [725.85, 813.8)_WarrantyCostBin
# 50897  [2045.1, 2133.05)_WarrantyCostBin
# 50898    [549.95, 637.9)_WarrantyCostBin
# 50899    [462.0, 549.95)_WarrantyCostBin
# 50900  [1869.2, 1957.15)_WarrantyCostBin
# 50901    [901.75, 989.7)_WarrantyCostBin
# 50902  [1165.6, 1253.55)_WarrantyCostBin
# 50903    [462.0, 549.95)_WarrantyCostBin
# 50904    [813.8, 901.75)_WarrantyCostBin
# 50905  [1077.65, 1165.6)_WarrantyCostBin
#
# [50906 rows x 24 columns]

# %%
df_Association.nunique()
# Out:
# Model                                   261
# SubModel                                 38
# VehYear                                  10
# IsBadBuy                                  2
# Auction                                   3
# VehicleAge                               10
# Make                                     32
# Engine                                  128
# Trim                                    129
# Transmission                              2
# WheelTypeID                               3
# Nationality                               2
# Size                                     12
# TopThreeAmericanName                      4
# BYRNO                                    72
# VNZIP1                                  152
# VNST                                     37
# IsOnlineSale                              2
# Doors                                     5
# PurchYearMonth                           24
# MMRAcquisitionAuctionAveragePriceBin     56
# VehBCostBin                              41
# VehOdoBin                                77
# WarrantyCostBin                          54
# dtype: int64

# %%
df_Association.isnull().sum()
# Out:
# Model                                   0
# SubModel                                0
# VehYear                                 0
# IsBadBuy                                0
# Auction                                 0
# VehicleAge                              0
# Make                                    0
# Engine                                  0
# Trim                                    0
# Transmission                            0
# WheelTypeID                             0
# Nationality                             0
# Size                                    0
# TopThreeAmericanName                    0
# BYRNO                                   0
# VNZIP1                                  0
# VNST                                    0
# IsOnlineSale                            0
# Doors                                   0
# PurchYearMonth                          0
# MMRAcquisitionAuctionAveragePriceBin    0
# VehBCostBin                             0
# VehOdoBin                               0
# WarrantyCostBin                         0
# dtype: int64

# %% [markdown]
# # Files in Output per le analisi successive

# %% [markdown]
# ** - File per il Clustering **

# %%
df_Clustering.to_csv(path_or_buf='Training_DU_Clustering.csv' ,index=False)

# %%
df_Clustering_forResultsAnalysis.to_csv(path_or_buf='Training_DU_Clustering_forResultsAnalysis.csv' ,index=False)

# %% [markdown]
# ** - File per la Classification **

# %%
#df_Classification.to_csv(path_or_buf='Training_DU_Classification.csv' ,index=False)

# %% [markdown]
# ** - File per la Association Rule **

# %%
df_Association.to_csv(path_or_buf='Training_DU_Association.csv' ,index=False)
