# %% [markdown]
# Primo approccio ad una correzione del dataset (date)

# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

from collections import defaultdict
from scipy.stats.stats import pearsonr

# %%
df = pd.read_csv('../../Dataset/training.csv')

# %%
df.head()
# Out:
#    RefId  IsBadBuy   PurchDate  Auction  VehYear  VehicleAge      Make  \
# 0    326         1  10/25/2010    ADESA     2008           2       KIA
# 1  42991         0   5/27/2009  MANHEIM     2006           3     DODGE
# 2  55273         0   3/18/2010    OTHER     2008           2     DODGE
# 3  29058         0    6/8/2009    OTHER     2005           4      FORD
# 4  34991         0    3/4/2009  MANHEIM     2005           4  CHRYSLER
#
#                   Model Trim          SubModel  ...  \
# 0               SPECTRA   EX       4D SEDAN EX  ...
# 1  STRATUS V6 2.7L V6 M  SXT  4D SEDAN SXT FFV  ...
# 2               CALIBER   SE          4D WAGON  ...
# 3  FREESTAR FWD V6 3.9L    S    PASSENGER 3.9L  ...
# 4  TOWN & COUNTRY FWD V  Bas      MINIVAN 3.3L  ...
#
#   MMRCurrentRetailAveragePrice MMRCurrentRetailCleanPrice  PRIMEUNIT AUCGUART  \
# 0                       9605.0                    10650.0        NaN      NaN
# 1                       6418.0                     7478.0        NaN      NaN
# 2                      10721.0                    11350.0        NaN      NaN
# 3                       5702.0                     7691.0        NaN      NaN
# 4                       6300.0                     7856.0        NaN      NaN
#
#    BYRNO VNZIP1 VNST VehBCost  IsOnlineSale  WarrantyCost
# 0   5546  33619   FL   6100.0             0           533
# 1  99750  32124   FL   4000.0             0          1630
# 2  99761  74135   OK   7500.0             0           693
# 3  99761  85018   AZ   4725.0             0          1633
# 4  20833  75236   TX   5670.0             0          1623
#
# [5 rows x 34 columns]

# %%
df.dtypes
# Out:
# RefId                                  int64
# IsBadBuy                               int64
# PurchDate                             object
# Auction                               object
# VehYear                                int64
# VehicleAge                             int64
# Make                                  object
# Model                                 object
# Trim                                  object
# SubModel                              object
# Color                                 object
# Transmission                          object
# WheelTypeID                          float64
# WheelType                             object
# VehOdo                                 int64
# Nationality                           object
# Size                                  object
# TopThreeAmericanName                  object
# MMRAcquisitionAuctionAveragePrice    float64
# MMRAcquisitionAuctionCleanPrice      float64
# MMRAcquisitionRetailAveragePrice     float64
# MMRAcquisitonRetailCleanPrice        float64
# MMRCurrentAuctionAveragePrice        float64
# MMRCurrentAuctionCleanPrice          float64
# MMRCurrentRetailAveragePrice         float64
# MMRCurrentRetailCleanPrice           float64
# PRIMEUNIT                             object
# AUCGUART                              object
# BYRNO                                  int64
# VNZIP1                                 int64
# VNST                                  object
# VehBCost                             float64
# IsOnlineSale                           int64
# WarrantyCost                           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58386 entries, 0 to 58385
# Data columns (total 34 columns):
# RefId                                58386 non-null int64
# IsBadBuy                             58386 non-null int64
# PurchDate                            58386 non-null object
# Auction                              58386 non-null object
# VehYear                              58386 non-null int64
# VehicleAge                           58386 non-null int64
# Make                                 58386 non-null object
# Model                                58386 non-null object
# Trim                                 56475 non-null object
# SubModel                             58379 non-null object
# Color                                58379 non-null object
# Transmission                         58378 non-null object
# WheelTypeID                          55813 non-null float64
# WheelType                            55809 non-null object
# VehOdo                               58386 non-null int64
# Nationality                          58382 non-null object
# Size                                 58382 non-null object
# TopThreeAmericanName                 58382 non-null object
# MMRAcquisitionAuctionAveragePrice    58373 non-null float64
# MMRAcquisitionAuctionCleanPrice      58373 non-null float64
# MMRAcquisitionRetailAveragePrice     58373 non-null float64
# MMRAcquisitonRetailCleanPrice        58373 non-null float64
# MMRCurrentAuctionAveragePrice        58141 non-null float64
# MMRCurrentAuctionCleanPrice          58141 non-null float64
# MMRCurrentRetailAveragePrice         58141 non-null float64
# MMRCurrentRetailCleanPrice           58141 non-null float64
# PRIMEUNIT                            2683 non-null object
# AUCGUART                             2683 non-null object
# BYRNO                                58386 non-null int64
# VNZIP1                               58386 non-null int64
# VNST                                 58386 non-null object
# VehBCost                             58386 non-null float64
# IsOnlineSale                         58386 non-null int64
# WarrantyCost                         58386 non-null int64
# dtypes: float64(10), int64(9), object(15)
# memory usage: 15.1+ MB

# %%
df['PurchDate']
# Out:
# 0        10/25/2010
# 1         5/27/2009
# 2         3/18/2010
# 3          6/8/2009
# 4          3/4/2009
#             ...
# 58381      3/9/2010
# 58382     1/26/2010
# 58383    10/28/2010
# 58384     12/1/2010
# 58385     10/8/2009
# Name: PurchDate, Length: 58386, dtype: object

# %%
for i in range(0,10):
    findRegex='^'+str(i)+'/'
    substitute='0'+str(i)+'/'
    df['PurchDate']=df['PurchDate'].str.replace(findRegex,substitute)
    findRegex='/'+str(i)+'/'
    substitute='/0'+str(i)+'/'
    df['PurchDate']=df['PurchDate'].str.replace(findRegex,substitute)

# %%
df['PurchDate']
# Out:
# 0        10/25/2010
# 1        05/27/2009
# 2        03/18/2010
# 3        06/08/2009
# 4        03/04/2009
#             ...
# 58381    03/09/2010
# 58382    01/26/2010
# 58383    10/28/2010
# 58384    12/01/2010
# 58385    10/08/2009
# Name: PurchDate, Length: 58386, dtype: object

# %%
#conversione e check correttezza date
df['PurchDate']=pd.to_datetime(df['PurchDate'], dayfirst=True)

# %%
(df == 0).sum(axis=0)
# Out:
# RefId                                    0
# IsBadBuy                             51178
# PurchDate                                0
# Auction                                  0
# VehYear                                  0
# VehicleAge                               1
# Make                                     0
# Model                                    0
# Trim                                     0
# SubModel                                 0
# Color                                    0
# Transmission                             0
# WheelTypeID                              4
# WheelType                                0
# VehOdo                                   0
# Nationality                              0
# Size                                     0
# TopThreeAmericanName                     0
# MMRAcquisitionAuctionAveragePrice      648
# MMRAcquisitionAuctionCleanPrice        552
# MMRAcquisitionRetailAveragePrice       648
# MMRAcquisitonRetailCleanPrice          648
# MMRCurrentAuctionAveragePrice          393
# MMRCurrentAuctionCleanPrice            300
# MMRCurrentRetailAveragePrice           393
# MMRCurrentRetailCleanPrice             393
# PRIMEUNIT                                0
# AUCGUART                                 0
# BYRNO                                    0
# VNZIP1                                   0
# VNST                                     0
# VehBCost                                 0
# IsOnlineSale                         56887
# WarrantyCost                             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# RefId                                    0
# IsBadBuy                                 0
# PurchDate                                0
# Auction                                  0
# VehYear                                  0
# VehicleAge                               0
# Make                                     0
# Model                                    0
# Trim                                  1911
# SubModel                                 7
# Color                                    7
# Transmission                             8
# WheelTypeID                           2573
# WheelType                             2577
# VehOdo                                   0
# Nationality                              4
# Size                                     4
# TopThreeAmericanName                     4
# MMRAcquisitionAuctionAveragePrice       13
# MMRAcquisitionAuctionCleanPrice         13
# MMRAcquisitionRetailAveragePrice        13
# MMRAcquisitonRetailCleanPrice           13
# MMRCurrentAuctionAveragePrice          245
# MMRCurrentAuctionCleanPrice            245
# MMRCurrentRetailAveragePrice           245
# MMRCurrentRetailCleanPrice             245
# PRIMEUNIT                            55703
# AUCGUART                             55703
# BYRNO                                    0
# VNZIP1                                   0
# VNST                                     0
# VehBCost                                 0
# IsOnlineSale                             0
# WarrantyCost                             0
# dtype: int64

# %%
counter=0;
for ID,PDate,VehYear,VehicleAge in zip(df['RefId'], df['PurchDate'], df['VehYear'], df['VehicleAge']):
    if(PDate.year-VehYear!=VehicleAge):
        print( df.loc[df['RefId']==ID, ['PurchDate','VehYear','VehicleAge']])
        counter=counter+1
# Out:
#        PurchDate  VehYear  VehicleAge
# 20050 2009-11-30     2005           5
#        PurchDate  VehYear  VehicleAge
# 21277 2009-12-21     2005           5
#        PurchDate  VehYear  VehicleAge
# 22979 2009-12-31     2006           4
#        PurchDate  VehYear  VehicleAge
# 26365 2009-08-26     2003           7
#        PurchDate  VehYear  VehicleAge
# 39989 2009-03-11     2006           4
#        PurchDate  VehYear  VehicleAge
# 56951 2009-12-15     2007           3

# %%
#prima era 4
#df.at[39989, 'VehicleAge']= 3

# %%
df["SubModel"].value_counts()
# Out:
# 4D SEDAN                 12234
# 4D SEDAN LS               3828
# 4D SEDAN SE               3111
# 4D WAGON                  1795
# MINIVAN 3.3L               996
#                          ...
# EXT CAB 4.0L SE              1
# 4D UTILITY 4.8L SLT          1
# CREW CAB LIMITED             1
# EXT CAB 8.1L LS              1
# EXT CAB 5.4L HERITAGE        1
# Name: SubModel, Length: 839, dtype: int64

# %%
df["Model"].value_counts()
# Out:
# PT CRUISER              1845
# IMPALA                  1616
# TAURUS                  1154
# CALIBER                 1108
# CARAVAN GRAND FWD V6    1021
#                         ...
# MATRIX 2WD Unspecifi       1
# XA 1.5L I4 EFI             1
# 4 RUNNER 4WD V6            1
# FOCUS 2.3L I4 MFI          1
# CIVIC 1.7L I-4 MPI S       1
# Name: Model, Length: 1029, dtype: int64

# %%
subdf=df.loc[df['Model']=='PT CRUISER',:]
subdf['SubModel'].value_counts()
# Out:
# 4D SEDAN                        1499
# 4D SEDAN TOURING                 138
# 4D SEDAN LIMITED                 113
# 2D CONVERTIBLE                    39
# 2D CONVERTIBLE TOURING            18
# 4D SEDAN LIMITED TURBO            11
# 4D SEDAN TOURING TURBO            10
# 4D SEDAN GT TURBO                  7
# 2D CONVERTIBLE DREAM CRUISER       6
# 4D SEDAN GT                        2
# 2D CONVERTIBLE GT                  2
# Name: SubModel, dtype: int64

# %%
subdf=subdf.loc[subdf["SubModel"]=="4D SEDAN",:]
subdf['Trim'].value_counts()
# Out:
# Bas    1078
# Tou     391
# GT       15
# Lim      15
# Name: Trim, dtype: int64

# %%
subdf=subdf.loc[subdf["Trim"]=="Bas",:]
subdf['VehYear'].value_counts()
# Out:
# 2008    285
# 2007    220
# 2006    209
# 2009     96
# 2004     94
# 2005     66
# 2003     49
# 2001     41
# 2002     18
# Name: VehYear, dtype: int64

# %%
subdf=subdf.loc[subdf["VehYear"]==2008,:]
subdf['PurchDate'] =pd.to_datetime(df['PurchDate'])
subdf=subdf.sort_values(['PurchDate','MMRCurrentAuctionAveragePrice'])

# %%
subdf2=subdf[['PurchDate',
            'MMRAcquisitionAuctionAveragePrice',
            'MMRAcquisitionAuctionCleanPrice',
            'MMRAcquisitionRetailAveragePrice',
            'MMRAcquisitonRetailCleanPrice',
            'MMRCurrentAuctionAveragePrice',     
            'MMRCurrentAuctionCleanPrice', 
            'MMRCurrentRetailAveragePrice',    
            'MMRCurrentRetailCleanPrice']]
subdf2
# Out:
#        PurchDate  MMRAcquisitionAuctionAveragePrice  \
# 29372 2009-01-12                             6521.0
# 49390 2009-01-12                             6521.0
# 35942 2009-01-12                             6521.0
# 41619 2009-01-12                             6521.0
# 56084 2009-01-12                             6521.0
# ...          ...                                ...
# 35594 2010-12-01                             6403.0
# 36368 2010-12-10                             6357.0
# 36233 2010-12-10                             6357.0
# 38542 2010-12-10                             6357.0
# 26946 2010-12-10                             6357.0
#
#        MMRAcquisitionAuctionCleanPrice  MMRAcquisitionRetailAveragePrice  \
# 29372                           7060.0                            7543.0
# 49390                           7060.0                            7543.0
# 35942                           7060.0                            7543.0
# 41619                           7060.0                            7543.0
# 56084                           7060.0                            7543.0
# ...                                ...                               ...
# 35594                           7003.0                            9777.0
# 36368                           7147.0                            9733.0
# 36233                           7147.0                            9733.0
# 38542                           7147.0                            9733.0
# 26946                           7147.0                            9733.0
#
#        MMRAcquisitonRetailCleanPrice  MMRCurrentAuctionAveragePrice  \
# 29372                         8125.0                         6366.0
# 49390                         8125.0                         6366.0
# 35942                         8125.0                         6656.0
# 41619                         8125.0                         6730.0
# 56084                         8125.0                         7169.0
# ...                              ...                            ...
# 35594                        10223.0                         7416.0
# 36368                        10497.0                         6326.0
# 36233                        10497.0                         6538.0
# 38542                        10497.0                         6538.0
# 26946                        10497.0                         7666.0
#
#        MMRCurrentAuctionCleanPrice  MMRCurrentRetailAveragePrice  \
# 29372                       6963.0                       10515.0
# 49390                       6963.0                       10515.0
# 35942                       7217.0                        9947.0
# 41619                       7324.0                        9926.0
# 56084                       7851.0                       10281.0
# ...                            ...                           ...
# 35594                       7934.0                       10403.0
# 36368                       7126.0                        9951.0
# 36233                       7487.0                        9995.0
# 38542                       7487.0                        9995.0
# 26946                       8940.0                       11835.0
#
#        MMRCurrentRetailCleanPrice
# 29372                     11501.0
# 49390                     11501.0
# 35942                     10437.0
# 41619                     10599.0
# 56084                     10890.0
# ...                           ...
# 35594                     10801.0
# 36368                     10806.0
# 36233                     10768.0
# 38542                     10768.0
# 26946                     13802.0
#
# [285 rows x 9 columns]

# %%
fig=plt.figure()
line1=plt.plot(range(0,285),subdf2['MMRAcquisitionAuctionAveragePrice'], label='AuctionAcqu')
#line1=plt.plot(range(0,285),subdf2['MMRAcquisitionRetailAveragePrice'], label='RetAcqu')
#line1=plt.plot(range(0,285),subdf2['MMRCurrentAuctionAveragePrice'], label='AuctionCurr')
#line1=plt.plot(range(0,285),subdf2['MMRCurrentRetailAveragePrice'], label='RetCurr')
plt.legend()

# %%
subdf2.corr()
# Out:
#                                    MMRAcquisitionAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.968686
# MMRAcquisitionRetailAveragePrice                            0.521215
# MMRAcquisitonRetailCleanPrice                               0.458569
# MMRCurrentAuctionAveragePrice                               0.061987
# MMRCurrentAuctionCleanPrice                                 0.012196
# MMRCurrentRetailAveragePrice                                0.072245
# MMRCurrentRetailCleanPrice                                 -0.000431
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                         0.968686
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.608404
# MMRAcquisitonRetailCleanPrice                             0.562479
# MMRCurrentAuctionAveragePrice                             0.031653
# MMRCurrentAuctionCleanPrice                               0.065089
# MMRCurrentRetailAveragePrice                              0.090191
# MMRCurrentRetailCleanPrice                                0.078354
#
#                                    MMRAcquisitionRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                          0.521215
# MMRAcquisitionAuctionCleanPrice                            0.608404
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.986785
# MMRCurrentAuctionAveragePrice                              0.118312
# MMRCurrentAuctionCleanPrice                                0.217147
# MMRCurrentRetailAveragePrice                               0.088656
# MMRCurrentRetailCleanPrice                                 0.106485
#
#                                    MMRAcquisitonRetailCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                       0.458569
# MMRAcquisitionAuctionCleanPrice                         0.562479
# MMRAcquisitionRetailAveragePrice                        0.986785
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.120769
# MMRCurrentAuctionCleanPrice                             0.244602
# MMRCurrentRetailAveragePrice                            0.096979
# MMRCurrentRetailCleanPrice                              0.137550
#
#                                    MMRCurrentAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                       0.061987
# MMRAcquisitionAuctionCleanPrice                         0.031653
# MMRAcquisitionRetailAveragePrice                        0.118312
# MMRAcquisitonRetailCleanPrice                           0.120769
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.887468
# MMRCurrentRetailAveragePrice                            0.555075
# MMRCurrentRetailCleanPrice                              0.339187
#
#                                    MMRCurrentAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                     0.012196
# MMRAcquisitionAuctionCleanPrice                       0.065089
# MMRAcquisitionRetailAveragePrice                      0.217147
# MMRAcquisitonRetailCleanPrice                         0.244602
# MMRCurrentAuctionAveragePrice                         0.887468
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.594688
# MMRCurrentRetailCleanPrice                            0.556714
#
#                                    MMRCurrentRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                      0.072245
# MMRAcquisitionAuctionCleanPrice                        0.090191
# MMRAcquisitionRetailAveragePrice                       0.088656
# MMRAcquisitonRetailCleanPrice                          0.096979
# MMRCurrentAuctionAveragePrice                          0.555075
# MMRCurrentAuctionCleanPrice                            0.594688
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.872858
#
#                                    MMRCurrentRetailCleanPrice
# MMRAcquisitionAuctionAveragePrice                   -0.000431
# MMRAcquisitionAuctionCleanPrice                      0.078354
# MMRAcquisitionRetailAveragePrice                     0.106485
# MMRAcquisitonRetailCleanPrice                        0.137550
# MMRCurrentAuctionAveragePrice                        0.339187
# MMRCurrentAuctionCleanPrice                          0.556714
# MMRCurrentRetailAveragePrice                         0.872858
# MMRCurrentRetailCleanPrice                           1.000000

# %%
fig=plt.figure()
line1=plt.plot(range(0,285),subdf2['MMRAcquisitionAuctionCleanPrice'], label='AClean')
line1=plt.plot(range(0,285),subdf2['MMRAcquisitionAuctionAveragePrice'], label='AAverage')
plt.legend()

# %%
fig=plt.figure()
line1=plt.plot(range(0,285),subdf2['MMRAcquisitionAuctionAveragePrice'], label='AAverage')
line1=plt.plot(range(0,285),subdf2['MMRCurrentAuctionAveragePrice'], label='CurAAverage')
plt.legend()

# %%
fig=plt.figure()
line1=plt.plot(range(0,285),subdf2['MMRAcquisitionRetailAveragePrice'], label='AClean')
line1=plt.plot(range(0,285),subdf2['MMRAcquisitionAuctionAveragePrice'], label='AAverage')
plt.legend()

# %%
df.corr()
# Out:
#                                       RefId  IsBadBuy   VehYear  VehicleAge  \
# RefId                              1.000000  0.026249  0.012306   -0.027387
# IsBadBuy                           0.026249  1.000000 -0.156926    0.165325
# VehYear                            0.012306 -0.156926  1.000000   -0.958049
# VehicleAge                        -0.027387  0.165325 -0.958049    1.000000
# WheelTypeID                        0.013970 -0.047693  0.261366   -0.252018
# VehOdo                            -0.024775  0.082858 -0.283569    0.318778
# MMRAcquisitionAuctionAveragePrice -0.010061 -0.105793  0.582416   -0.567106
# MMRAcquisitionAuctionCleanPrice   -0.014251 -0.099315  0.533807   -0.519897
# MMRAcquisitionRetailAveragePrice  -0.030702 -0.084514  0.582414   -0.462299
# MMRAcquisitonRetailCleanPrice     -0.032965 -0.080712  0.540206   -0.427526
# MMRCurrentAuctionAveragePrice     -0.006934 -0.106130  0.591968   -0.576914
# MMRCurrentAuctionCleanPrice       -0.011416 -0.101036  0.549345   -0.533646
# MMRCurrentRetailAveragePrice      -0.020314 -0.100786  0.599415   -0.505322
# MMRCurrentRetailCleanPrice        -0.023234 -0.097195  0.559579   -0.470640
# BYRNO                              0.035519 -0.059412  0.281799   -0.269907
# VNZIP1                             0.135599  0.006393  0.069976   -0.076617
# VehBCost                          -0.011589 -0.098132  0.349672   -0.311903
# IsOnlineSale                      -0.047771 -0.003969  0.057316   -0.024659
# WarrantyCost                      -0.024420  0.050259 -0.267739    0.257996
#
#                                    WheelTypeID    VehOdo  \
# RefId                                 0.013970 -0.024775
# IsBadBuy                             -0.047693  0.082858
# VehYear                               0.261366 -0.283569
# VehicleAge                           -0.252018  0.318778
# WheelTypeID                           1.000000 -0.212432
# VehOdo                               -0.212432  1.000000
# MMRAcquisitionAuctionAveragePrice    -0.094658 -0.018381
# MMRAcquisitionAuctionCleanPrice      -0.129608  0.023717
# MMRAcquisitionRetailAveragePrice     -0.071736  0.029107
# MMRAcquisitonRetailCleanPrice        -0.101796  0.061407
# MMRCurrentAuctionAveragePrice        -0.086798 -0.030141
# MMRCurrentAuctionCleanPrice          -0.120046  0.010755
# MMRCurrentRetailAveragePrice         -0.072684  0.013719
# MMRCurrentRetailCleanPrice           -0.101250  0.046070
# BYRNO                                 0.189817 -0.292230
# VNZIP1                                0.007846 -0.053547
# VehBCost                             -0.160986 -0.064436
# IsOnlineSale                         -0.011364  0.030994
# WarrantyCost                         -0.133688  0.411273
#
#                                    MMRAcquisitionAuctionAveragePrice  \
# RefId                                                      -0.010061
# IsBadBuy                                                   -0.105793
# VehYear                                                     0.582416
# VehicleAge                                                 -0.567106
# WheelTypeID                                                -0.094658
# VehOdo                                                     -0.018381
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.990218
# MMRAcquisitionRetailAveragePrice                            0.910185
# MMRAcquisitonRetailCleanPrice                               0.909832
# MMRCurrentAuctionAveragePrice                               0.937482
# MMRCurrentAuctionCleanPrice                                 0.931919
# MMRCurrentRetailAveragePrice                                0.871220
# MMRCurrentRetailCleanPrice                                  0.870424
# BYRNO                                                       0.108806
# VNZIP1                                                      0.047112
# VehBCost                                                    0.789354
# IsOnlineSale                                                0.038029
# WarrantyCost                                               -0.049682
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# RefId                                                    -0.014251
# IsBadBuy                                                 -0.099315
# VehYear                                                   0.533807
# VehicleAge                                               -0.519897
# WheelTypeID                                              -0.129608
# VehOdo                                                    0.023717
# MMRAcquisitionAuctionAveragePrice                         0.990218
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.902339
# MMRAcquisitonRetailCleanPrice                             0.917934
# MMRCurrentAuctionAveragePrice                             0.923144
# MMRCurrentAuctionCleanPrice                               0.931599
# MMRCurrentRetailAveragePrice                              0.860055
# MMRCurrentRetailCleanPrice                                0.870604
# BYRNO                                                     0.062818
# VNZIP1                                                    0.041810
# VehBCost                                                  0.781123
# IsOnlineSale                                              0.037896
# WarrantyCost                                             -0.019607
#
#                                    MMRAcquisitionRetailAveragePrice  \
# RefId                                                     -0.030702
# IsBadBuy                                                  -0.084514
# VehYear                                                    0.582414
# VehicleAge                                                -0.462299
# WheelTypeID                                               -0.071736
# VehOdo                                                     0.029107
# MMRAcquisitionAuctionAveragePrice                          0.910185
# MMRAcquisitionAuctionCleanPrice                            0.902339
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.990085
# MMRCurrentAuctionAveragePrice                              0.851330
# MMRCurrentAuctionCleanPrice                                0.848776
# MMRCurrentRetailAveragePrice                               0.912747
# MMRCurrentRetailCleanPrice                                 0.905523
# BYRNO                                                      0.107988
# VNZIP1                                                     0.036402
# VehBCost                                                   0.745718
# IsOnlineSale                                               0.079767
# WarrantyCost                                              -0.053507
#
#                                    MMRAcquisitonRetailCleanPrice  \
# RefId                                                  -0.032965
# IsBadBuy                                               -0.080712
# VehYear                                                 0.540206
# VehicleAge                                             -0.427526
# WheelTypeID                                            -0.101796
# VehOdo                                                  0.061407
# MMRAcquisitionAuctionAveragePrice                       0.909832
# MMRAcquisitionAuctionCleanPrice                         0.917934
# MMRAcquisitionRetailAveragePrice                        0.990085
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.846393
# MMRCurrentAuctionCleanPrice                             0.854986
# MMRCurrentRetailAveragePrice                            0.902680
# MMRCurrentRetailCleanPrice                              0.906231
# BYRNO                                                   0.069857
# VNZIP1                                                  0.032120
# VehBCost                                                0.744622
# IsOnlineSale                                            0.076735
# WarrantyCost                                           -0.026708
#
#                                    MMRCurrentAuctionAveragePrice  \
# RefId                                                  -0.006934
# IsBadBuy                                               -0.106130
# VehYear                                                 0.591968
# VehicleAge                                             -0.576914
# WheelTypeID                                            -0.086798
# VehOdo                                                 -0.030141
# MMRAcquisitionAuctionAveragePrice                       0.937482
# MMRAcquisitionAuctionCleanPrice                         0.923144
# MMRAcquisitionRetailAveragePrice                        0.851330
# MMRAcquisitonRetailCleanPrice                           0.846393
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.990244
# MMRCurrentRetailAveragePrice                            0.915147
# MMRCurrentRetailCleanPrice                              0.912305
# BYRNO                                                   0.112075
# VNZIP1                                                  0.051706
# VehBCost                                                0.778253
# IsOnlineSale                                            0.039513
# WarrantyCost                                           -0.056893
#
#                                    MMRCurrentAuctionCleanPrice  \
# RefId                                                -0.011416
# IsBadBuy                                             -0.101036
# VehYear                                               0.549345
# VehicleAge                                           -0.533646
# WheelTypeID                                          -0.120046
# VehOdo                                                0.010755
# MMRAcquisitionAuctionAveragePrice                     0.931919
# MMRAcquisitionAuctionCleanPrice                       0.931599
# MMRAcquisitionRetailAveragePrice                      0.848776
# MMRAcquisitonRetailCleanPrice                         0.854986
# MMRCurrentAuctionAveragePrice                         0.990244
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.908620
# MMRCurrentRetailCleanPrice                            0.921638
# BYRNO                                                 0.068937
# VNZIP1                                                0.046236
# VehBCost                                              0.774637
# IsOnlineSale                                          0.040003
# WarrantyCost                                         -0.028245
#
#                                    MMRCurrentRetailAveragePrice  \
# RefId                                                 -0.020314
# IsBadBuy                                              -0.100786
# VehYear                                                0.599415
# VehicleAge                                            -0.505322
# WheelTypeID                                           -0.072684
# VehOdo                                                 0.013719
# MMRAcquisitionAuctionAveragePrice                      0.871220
# MMRAcquisitionAuctionCleanPrice                        0.860055
# MMRAcquisitionRetailAveragePrice                       0.912747
# MMRAcquisitonRetailCleanPrice                          0.902680
# MMRCurrentAuctionAveragePrice                          0.915147
# MMRCurrentAuctionCleanPrice                            0.908620
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.989693
# BYRNO                                                  0.111283
# VNZIP1                                                 0.041793
# VehBCost                                               0.756790
# IsOnlineSale                                           0.079203
# WarrantyCost                                          -0.058965
#
#                                    MMRCurrentRetailCleanPrice     BYRNO  \
# RefId                                               -0.023234  0.035519
# IsBadBuy                                            -0.097195 -0.059412
# VehYear                                              0.559579  0.281799
# VehicleAge                                          -0.470640 -0.269907
# WheelTypeID                                         -0.101250  0.189817
# VehOdo                                               0.046070 -0.292230
# MMRAcquisitionAuctionAveragePrice                    0.870424  0.108806
# MMRAcquisitionAuctionCleanPrice                      0.870604  0.062818
# MMRAcquisitionRetailAveragePrice                     0.905523  0.107988
# MMRAcquisitonRetailCleanPrice                        0.906231  0.069857
# MMRCurrentAuctionAveragePrice                        0.912305  0.112075
# MMRCurrentAuctionCleanPrice                          0.921638  0.068937
# MMRCurrentRetailAveragePrice                         0.989693  0.111283
# MMRCurrentRetailCleanPrice                           1.000000  0.074541
# BYRNO                                                0.074541  1.000000
# VNZIP1                                               0.037454  0.039352
# VehBCost                                             0.756551  0.046551
# IsOnlineSale                                         0.076463 -0.143585
# WarrantyCost                                        -0.032932 -0.089497
#
#                                      VNZIP1  VehBCost  IsOnlineSale  \
# RefId                              0.135599 -0.011589     -0.047771
# IsBadBuy                           0.006393 -0.098132     -0.003969
# VehYear                            0.069976  0.349672      0.057316
# VehicleAge                        -0.076617 -0.311903     -0.024659
# WheelTypeID                        0.007846 -0.160986     -0.011364
# VehOdo                            -0.053547 -0.064436      0.030994
# MMRAcquisitionAuctionAveragePrice  0.047112  0.789354      0.038029
# MMRAcquisitionAuctionCleanPrice    0.041810  0.781123      0.037896
# MMRAcquisitionRetailAveragePrice   0.036402  0.745718      0.079767
# MMRAcquisitonRetailCleanPrice      0.032120  0.744622      0.076735
# MMRCurrentAuctionAveragePrice      0.051706  0.778253      0.039513
# MMRCurrentAuctionCleanPrice        0.046236  0.774637      0.040003
# MMRCurrentRetailAveragePrice       0.041793  0.756790      0.079203
# MMRCurrentRetailCleanPrice         0.037454  0.756551      0.076463
# BYRNO                              0.039352  0.046551     -0.143585
# VNZIP1                             1.000000  0.017150      0.026640
# VehBCost                           0.017150  1.000000      0.032489
# IsOnlineSale                       0.026640  0.032489      1.000000
# WarrantyCost                      -0.039594 -0.033901      0.006099
#
#                                    WarrantyCost
# RefId                                 -0.024420
# IsBadBuy                               0.050259
# VehYear                               -0.267739
# VehicleAge                             0.257996
# WheelTypeID                           -0.133688
# VehOdo                                 0.411273
# MMRAcquisitionAuctionAveragePrice     -0.049682
# MMRAcquisitionAuctionCleanPrice       -0.019607
# MMRAcquisitionRetailAveragePrice      -0.053507
# MMRAcquisitonRetailCleanPrice         -0.026708
# MMRCurrentAuctionAveragePrice         -0.056893
# MMRCurrentAuctionCleanPrice           -0.028245
# MMRCurrentRetailAveragePrice          -0.058965
# MMRCurrentRetailCleanPrice            -0.032932
# BYRNO                                 -0.089497
# VNZIP1                                -0.039594
# VehBCost                              -0.033901
# IsOnlineSale                           0.006099
# WarrantyCost                           1.000000

# %%
df['BYRNO'].value_counts()
# Out:
# 99761    3191
# 18880    2852
# 835      2398
# 3453     2362
# 22916    2285
#          ...
# 10420       3
# 1157        1
# 10425       1
# 99741       1
# 1086        1
# Name: BYRNO, Length: 72, dtype: int64

# %%
subdf3=df.loc[df['Model']=='CALIBER',:]
subdf3['SubModel'].value_counts()
# Out:
# 4D WAGON            884
# 4D WAGON SXT        203
# 4D WAGON SE          16
# 4D WAGON R/T AWD      3
# 4D WAGON R/T          2
# Name: SubModel, dtype: int64

# %%
subdf3=subdf3.loc[subdf3['SubModel']=='4D WAGON',:]
subdf3['Trim'].value_counts()
# Out:
# SE     754
# Bas    130
# Name: Trim, dtype: int64

# %%
subdf3=subdf3.loc[subdf3['Trim']=='SE',:]
subdf3['VehYear'].value_counts()
# Out:
# 2008    754
# Name: VehYear, dtype: int64

# %%
subdf3['PurchDate'] =pd.to_datetime(subdf3['PurchDate'])
subdf3=subdf3.sort_values('PurchDate')
subdf3
# Out:
#        RefId  IsBadBuy  PurchDate Auction  VehYear  VehicleAge   Make  \
# 26844  53706         0 2009-02-11   OTHER     2008           1  DODGE
# 52951  53677         0 2009-02-11   OTHER     2008           1  DODGE
# 49722  53718         0 2009-02-11   OTHER     2008           1  DODGE
# 49635  53713         0 2009-02-11   OTHER     2008           1  DODGE
# 53383  53728         0 2009-02-11   OTHER     2008           1  DODGE
# ...      ...       ...        ...     ...      ...         ...    ...
# 55082  55255         0 2010-12-03   OTHER     2008           2  DODGE
# 55362  55232         0 2010-12-03   OTHER     2008           2  DODGE
# 1217   55252         0 2010-12-03   OTHER     2008           2  DODGE
# 46772  55238         0 2010-12-03   OTHER     2008           2  DODGE
# 27112  55256         0 2010-12-03   OTHER     2008           2  DODGE
#
#          Model Trim  SubModel  ... MMRCurrentRetailAveragePrice  \
# 26844  CALIBER   SE  4D WAGON  ...                       7911.0
# 52951  CALIBER   SE  4D WAGON  ...                      10921.0
# 49722  CALIBER   SE  4D WAGON  ...                       7911.0
# 49635  CALIBER   SE  4D WAGON  ...                      11237.0
# 53383  CALIBER   SE  4D WAGON  ...                      10834.0
# ...        ...  ...       ...  ...                          ...
# 55082  CALIBER   SE  4D WAGON  ...                      11509.0
# 55362  CALIBER   SE  4D WAGON  ...                      11691.0
# 1217   CALIBER   SE  4D WAGON  ...                      11270.0
# 46772  CALIBER   SE  4D WAGON  ...                      11321.0
# 27112  CALIBER   SE  4D WAGON  ...                      11453.0
#
#       MMRCurrentRetailCleanPrice  PRIMEUNIT AUCGUART  BYRNO VNZIP1 VNST  \
# 26844                     8426.0        NaN      NaN  99761  74135   OK
# 52951                    11542.0        NaN      NaN  99761  74135   OK
# 49722                     8426.0        NaN      NaN  99761  74135   OK
# 49635                    11739.0        NaN      NaN  99761  74135   OK
# 53383                    11413.0        NaN      NaN  99761  74135   OK
# ...                          ...        ...      ...    ...    ...  ...
# 55082                    12387.0        NaN      NaN  99761  74135   OK
# 55362                    12701.0        NaN      NaN  99761  74135   OK
# 1217                     11713.0        NaN      NaN  99761  74135   OK
# 46772                    11966.0        NaN      NaN  99761  74135   OK
# 27112                    12309.0        NaN      NaN  99761  74135   OK
#
#       VehBCost  IsOnlineSale  WarrantyCost
# 26844   6600.0             0           754
# 52951   6600.0             0           754
# 49722   6600.0             0           754
# 49635   6600.0             0           754
# 53383   6600.0             0           754
# ...        ...           ...           ...
# 55082   7450.0             0           693
# 55362   7450.0             0           693
# 1217    7450.0             0           693
# 46772   7450.0             0           693
# 27112   7450.0             0           754
#
# [754 rows x 34 columns]

# %%
tmp=subdf3.loc[subdf3['PurchDate']=='2009-02-11']
tmp=tmp.loc[:,['PurchDate','Color','Transmission','WheelType','VehOdo','MMRAcquisitionAuctionAveragePrice','MMRCurrentAuctionAveragePrice']]
tmp['Color'].value_counts()
tmp=tmp.loc[tmp['Color']=='RED']
tmp
# Out:
#        PurchDate Color Transmission WheelType  VehOdo  \
# 52951 2009-02-11   RED         AUTO    Covers   51026
# 53383 2009-02-11   RED         AUTO    Covers   50268
# 55054 2009-02-11   RED         AUTO     Alloy   50672
# 39550 2009-02-11   RED         AUTO    Covers   50132
# 39272 2009-02-11   RED         AUTO    Covers   50733
# 35377 2009-02-11   RED         AUTO    Covers   51274
# 57334 2009-02-11   RED         AUTO    Covers   47405
#
#        MMRAcquisitionAuctionAveragePrice  MMRCurrentAuctionAveragePrice
# 52951                             6948.0                         6967.0
# 53383                             6948.0                         7269.0
# 55054                             6948.0                         6966.0
# 39550                             6948.0                         6966.0
# 39272                             6948.0                         6966.0
# 35377                             6948.0                         7524.0
# 57334                             6948.0                         6966.0

# %%
df.loc[[35377,39272],]
# Out:
#        RefId  IsBadBuy  PurchDate Auction  VehYear  VehicleAge   Make  \
# 35377  53734         0 2009-02-11   OTHER     2008           1  DODGE
# 39272  53687         0 2009-02-11   OTHER     2008           1  DODGE
#
#          Model Trim  SubModel  ... MMRCurrentRetailAveragePrice  \
# 35377  CALIBER   SE  4D WAGON  ...                      10564.0
# 39272  CALIBER   SE  4D WAGON  ...                      11237.0
#
#       MMRCurrentRetailCleanPrice  PRIMEUNIT AUCGUART  BYRNO VNZIP1 VNST  \
# 35377                    11431.0        NaN      NaN  99761  74135   OK
# 39272                    11739.0        NaN      NaN  99761  74135   OK
#
#       VehBCost  IsOnlineSale  WarrantyCost
# 35377   6600.0             0           754
# 39272   6600.0             0           754
#
# [2 rows x 34 columns]

# %%
subdf3=subdf3[['PurchDate',
            'MMRAcquisitionAuctionAveragePrice',
            'MMRAcquisitionAuctionCleanPrice',
            'MMRAcquisitionRetailAveragePrice',
             'MMRAcquisitonRetailCleanPrice',
            'MMRCurrentAuctionAveragePrice',     
            'MMRCurrentAuctionCleanPrice', 
            'MMRCurrentRetailAveragePrice',    
            'MMRCurrentRetailCleanPrice']]


fig=plt.figure()
line1=plt.plot(range(0,754),subdf3['MMRAcquisitionAuctionAveragePrice'], label='AuctionAcqu')
line1=plt.plot(range(0,754),subdf3['MMRCurrentAuctionAveragePrice'], label='AuctionCurr')
plt.legend()

# %%
fig=plt.figure()
line1=plt.plot(range(0,754),subdf3['MMRAcquisitionRetailAveragePrice'], label='RetAcqu')
line1=plt.plot(range(0,754),subdf3['MMRCurrentRetailAveragePrice'], label='RetCurr')
plt.legend()

# %%
subdf3.corr()
# Out:
#                                    MMRAcquisitionAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.994681
# MMRAcquisitionRetailAveragePrice                            0.918942
# MMRAcquisitonRetailCleanPrice                               0.921850
# MMRCurrentAuctionAveragePrice                               0.093599
# MMRCurrentAuctionCleanPrice                                 0.156613
# MMRCurrentRetailAveragePrice                                0.109015
# MMRCurrentRetailCleanPrice                                  0.146117
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                         0.994681
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.922193
# MMRAcquisitonRetailCleanPrice                             0.931830
# MMRCurrentAuctionAveragePrice                             0.090883
# MMRCurrentAuctionCleanPrice                               0.169283
# MMRCurrentRetailAveragePrice                              0.100342
# MMRCurrentRetailCleanPrice                                0.145860
#
#                                    MMRAcquisitionRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                          0.918942
# MMRAcquisitionAuctionCleanPrice                            0.922193
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.996845
# MMRCurrentAuctionAveragePrice                              0.181898
# MMRCurrentAuctionCleanPrice                                0.281991
# MMRCurrentRetailAveragePrice                               0.164710
# MMRCurrentRetailCleanPrice                                 0.228061
#
#                                    MMRAcquisitonRetailCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                       0.921850
# MMRAcquisitionAuctionCleanPrice                         0.931830
# MMRAcquisitionRetailAveragePrice                        0.996845
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.176318
# MMRCurrentAuctionCleanPrice                             0.282121
# MMRCurrentRetailAveragePrice                            0.154817
# MMRCurrentRetailCleanPrice                              0.220706
#
#                                    MMRCurrentAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                       0.093599
# MMRAcquisitionAuctionCleanPrice                         0.090883
# MMRAcquisitionRetailAveragePrice                        0.181898
# MMRAcquisitonRetailCleanPrice                           0.176318
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.837130
# MMRCurrentRetailAveragePrice                            0.551014
# MMRCurrentRetailCleanPrice                              0.490166
#
#                                    MMRCurrentAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                     0.156613
# MMRAcquisitionAuctionCleanPrice                       0.169283
# MMRAcquisitionRetailAveragePrice                      0.281991
# MMRAcquisitonRetailCleanPrice                         0.282121
# MMRCurrentAuctionAveragePrice                         0.837130
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.543521
# MMRCurrentRetailCleanPrice                            0.679025
#
#                                    MMRCurrentRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                      0.109015
# MMRAcquisitionAuctionCleanPrice                        0.100342
# MMRAcquisitionRetailAveragePrice                       0.164710
# MMRAcquisitonRetailCleanPrice                          0.154817
# MMRCurrentAuctionAveragePrice                          0.551014
# MMRCurrentAuctionCleanPrice                            0.543521
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.922984
#
#                                    MMRCurrentRetailCleanPrice
# MMRAcquisitionAuctionAveragePrice                    0.146117
# MMRAcquisitionAuctionCleanPrice                      0.145860
# MMRAcquisitionRetailAveragePrice                     0.228061
# MMRAcquisitonRetailCleanPrice                        0.220706
# MMRCurrentAuctionAveragePrice                        0.490166
# MMRCurrentAuctionCleanPrice                          0.679025
# MMRCurrentRetailAveragePrice                         0.922984
# MMRCurrentRetailCleanPrice                           1.000000

# %%
fig=plt.figure()
line1=plt.plot(range(0,754),subdf3['MMRAcquisitionAuctionAveragePrice'], label='AverAcqu')
line1=plt.plot(range(0,754),subdf3['MMRAcquisitionAuctionCleanPrice'], label='CleanCurr')
line1=plt.plot(range(0,754),subdf3['MMRAcquisitionRetailAveragePrice'], label='CleanCurr')
line1=plt.plot(range(0,754),subdf3['MMRAcquisitonRetailCleanPrice'], label='CleanCurr')
plt.legend()

# %%
subdf4=df.loc[df['Model']=='IMPALA',:]
subdf4['SubModel'].value_counts()
subdf4=subdf4.loc[subdf4['SubModel']=='4D SEDAN LS',:]
subdf4['Trim'].value_counts()
subdf4=subdf4.loc[subdf4['Trim']=='LS',:]
subdf4['VehYear'].value_counts()
subdf4=subdf4.loc[subdf4['VehYear']==2007,:]
subdf4['PurchDate'] =pd.to_datetime(subdf4['PurchDate'])
subdf4=subdf4.sort_values('PurchDate')

# %%
fig=plt.figure()
line1=plt.plot(range(0,741),subdf4['MMRAcquisitionAuctionAveragePrice'], label='AAP')
#line1=plt.plot(range(0,741),subdf3['MMRAcquisitionAuctionCleanPrice'], label='CleanCurr')
line1=plt.plot(range(0,741),subdf4['MMRAcquisitionRetailAveragePrice'], label='RAP')
#line1=plt.plot(range(0,741),subdf3['MMRAcquisitonRetailCleanPrice'], label='CleanCurr')
plt.legend()

# %%
subdf4=subdf4[['PurchDate',
            'MMRAcquisitionAuctionAveragePrice',
            'MMRAcquisitionAuctionCleanPrice',
            'MMRAcquisitionRetailAveragePrice',
            'MMRAcquisitonRetailCleanPrice',
            'MMRCurrentAuctionAveragePrice',     
            'MMRCurrentAuctionCleanPrice', 
            'MMRCurrentRetailAveragePrice',    
            'MMRCurrentRetailCleanPrice']]
subdf4.corr()
# Out:
#                                    MMRAcquisitionAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.992913
# MMRAcquisitionRetailAveragePrice                            0.921652
# MMRAcquisitonRetailCleanPrice                               0.919396
# MMRCurrentAuctionAveragePrice                               0.137241
# MMRCurrentAuctionCleanPrice                                 0.105533
# MMRCurrentRetailAveragePrice                                0.153686
# MMRCurrentRetailCleanPrice                                  0.106755
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                         0.992913
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.913435
# MMRAcquisitonRetailCleanPrice                             0.921083
# MMRCurrentAuctionAveragePrice                             0.108449
# MMRCurrentAuctionCleanPrice                               0.086733
# MMRCurrentRetailAveragePrice                              0.124689
# MMRCurrentRetailCleanPrice                                0.086979
#
#                                    MMRAcquisitionRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                          0.921652
# MMRAcquisitionAuctionCleanPrice                            0.913435
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.991370
# MMRCurrentAuctionAveragePrice                              0.146549
# MMRCurrentAuctionCleanPrice                                0.113137
# MMRCurrentRetailAveragePrice                               0.164795
# MMRCurrentRetailCleanPrice                                 0.108739
#
#                                    MMRAcquisitonRetailCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                       0.919396
# MMRAcquisitionAuctionCleanPrice                         0.921083
# MMRAcquisitionRetailAveragePrice                        0.991370
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.141584
# MMRCurrentAuctionCleanPrice                             0.117087
# MMRCurrentRetailAveragePrice                            0.162077
# MMRCurrentRetailCleanPrice                              0.115426
#
#                                    MMRCurrentAuctionAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                       0.137241
# MMRAcquisitionAuctionCleanPrice                         0.108449
# MMRAcquisitionRetailAveragePrice                        0.146549
# MMRAcquisitonRetailCleanPrice                           0.141584
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.982078
# MMRCurrentRetailAveragePrice                            0.914315
# MMRCurrentRetailCleanPrice                              0.923857
#
#                                    MMRCurrentAuctionCleanPrice  \
# MMRAcquisitionAuctionAveragePrice                     0.105533
# MMRAcquisitionAuctionCleanPrice                       0.086733
# MMRAcquisitionRetailAveragePrice                      0.113137
# MMRAcquisitonRetailCleanPrice                         0.117087
# MMRCurrentAuctionAveragePrice                         0.982078
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.884543
# MMRCurrentRetailCleanPrice                            0.927163
#
#                                    MMRCurrentRetailAveragePrice  \
# MMRAcquisitionAuctionAveragePrice                      0.153686
# MMRAcquisitionAuctionCleanPrice                        0.124689
# MMRAcquisitionRetailAveragePrice                       0.164795
# MMRAcquisitonRetailCleanPrice                          0.162077
# MMRCurrentAuctionAveragePrice                          0.914315
# MMRCurrentAuctionCleanPrice                            0.884543
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.960618
#
#                                    MMRCurrentRetailCleanPrice
# MMRAcquisitionAuctionAveragePrice                    0.106755
# MMRAcquisitionAuctionCleanPrice                      0.086979
# MMRAcquisitionRetailAveragePrice                     0.108739
# MMRAcquisitonRetailCleanPrice                        0.115426
# MMRCurrentAuctionAveragePrice                        0.923857
# MMRCurrentAuctionCleanPrice                          0.927163
# MMRCurrentRetailAveragePrice                         0.960618
# MMRCurrentRetailCleanPrice                           1.000000

# %%
fig=plt.figure()
line1=plt.plot(range(0,741),subdf4['MMRCurrentAuctionAveragePrice'], label='CAAP')
line1=plt.plot(range(0,741),subdf4['MMRAcquisitionAuctionAveragePrice'], label='AAAP')
line1=plt.plot(range(0,741),subdf4['MMRCurrentRetailAveragePrice'], label='CRAP')
#line1=plt.plot(range(0,741),subdf3['MMRAcquisitonRetailCleanPrice'], label='CleanCurr')
plt.legend()

# %%
df.to_csv(path_or_buf=r'C:\Users\Michele\Documents\unipi\DM\progetto\DataUnderstanding\Python\data.csv', index=False)
